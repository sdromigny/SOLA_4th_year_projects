# %% [markdown]
# <a href="https://colab.research.google.com/github/sdromigny/SOLA_4th_year_projects/blob/main/Copie_de_Pykonal_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pykonal
#!pip install "numpy<2.0"
# Out:
# Collecting pykonal
#   Downloading pykonal-0.4.1.tar.gz (10.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 4.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: cython>=0.29.14 in /usr/local/lib/python3.12/dist-packages (from pykonal) (3.0.12)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from pykonal) (3.15.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pykonal) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pykonal) (1.16.3)
# Building wheels for collected packages: pykonal
#   Building wheel for pykonal (pyproject.toml) ... done
#   Created wheel for pykonal: filename=pykonal-0.4.1-cp312-cp312-linux_x86_64.whl size=13937082 sha256=3ad839f5909c810d09024134aec339959b04ad2a1c417cce8cb0319414054569
#   Stored in directory: /root/.cache/pip/wheels/a4/be/31/71da2d81557632858244e3a3ab92963e7c382fe0dc73c32bef
# Successfully built pykonal
# Installing collected packages: pykonal
# Successfully installed pykonal-0.4.1

# %%
import numpy as np
import pykonal
import matplotlib.pyplot as plt


# --- Safety patch for NumPy >= 2.0 ---
if not hasattr(np, "infty"):
    np.infty = np.inf

# 1) Initialize solver (Cartesian coordinates)
solver = pykonal.EikonalSolver(coord_sys="cartesian")

# 2) Define grid geometry
solver.velocity.min_coords = (0.0, 0.0, 0.0)       # origin (x0, y0, z0)
solver.velocity.node_intervals = (1.0, 1.0, 1.0)   # dx, dy, dz
solver.velocity.npts = (10, 10, 10)                # nx, ny, nz

# 3) Define velocity field
nx, ny, nz = solver.velocity.npts
vel = np.empty((nx, ny, nz))

# first layer (z index = 0)
vel[:, :, 0] = 5.5
# all other layers (z = 1..9)
vel[:, :, 1:] = 5.76

solver.velocity.values = vel

# --- optional: verify ---
print("Velocity model shape:", vel.shape)
print("Top layer velocity:", vel[0,0,0])
print("Second layer velocity:", vel[0,0,1])

# 4) Define a source on the top layer
src_idx = (5, 5, 9)
solver.traveltime.values[src_idx] = 0.0
solver.unknown[src_idx] = False
solver.trial.push(*src_idx)

# 5) Solve travel times
solver.solve()

# --- optional check: travel time at some point ---
end_idx = (9, 9, 0)
tt = solver.traveltime.values[end_idx]
print(f"Travel time to node {end_idx}: {tt:.3f} s")

# --- optional: ray tracing (ensure NumPy patch above) ---
end_coord = np.array([9.0, 9.0, 0])
ray = solver.trace_ray(end_coord)
print("Ray path shape:", ray.shape)
# Out:
# Velocity model shape: (10, 10, 10)
# Top layer velocity: 5.5
# Second layer velocity: 5.76
# Travel time to node (9, 9, 0): 1.940 s
# Ray path shape: (43, 3)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401
from matplotlib import cm

# --- prepare coordinates and fields ---
min_x, min_y, min_z = solver.velocity.min_coords
dx, dy, dz = solver.velocity.node_intervals
nx, ny, nz = solver.velocity.npts

# Create coordinate arrays (grid centers at integer node indices times interval)
xs = min_x + np.arange(nx) * dx
ys = min_y + np.arange(ny) * dy
zs = min_z + np.arange(nz) * dz
X, Y, Z = np.meshgrid(xs, ys, zs, indexing='ij')  # shape (nx,ny,nz)

# Flatten for scatter plotting
coords = np.column_stack((X.ravel(), Y.ravel(), Z.ravel()))
tt_vals = solver.traveltime.values.ravel()
vel_vals = solver.velocity.values.ravel()

# ---------------------------
# 1) 3D scatter colored by travel time + 2D mid-slice of travel time
# ---------------------------
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(211, projection='3d')  # top: 3D scatter

sc = ax.scatter(coords[:, 0], coords[:, 1], -coords[:, 2],
                c=tt_vals, cmap='viridis', s=20, alpha=0.9)
ax.set_title('3D travel-time field (scatter)')
ax.set_xlabel('x'); ax.set_ylabel('y'); ax.set_zlabel('z')

# source and endpoint markers (if available)
try:
    ax.scatter([src_coord[0]], [src_coord[1]], [-src_coord[2]], c='k', s=60, label='source')
    ax.scatter([end_coord[0]], [end_coord[1]], [-end_coord[2]], c='r', s=60, label='end')
    ax.legend()
except NameError:
    pass

# colorbar for travel time
mappable_tt = cm.ScalarMappable(cmap='viridis', norm=plt.Normalize(vmin=tt_vals.min(), vmax=tt_vals.max()))
mappable_tt.set_array(tt_vals)
fig.colorbar(mappable_tt, ax=ax, shrink=0.5, label='Travel time (s)')

# bottom: mid-z slice (2D image) for travel time
ax2 = fig.add_subplot(212)
mid_k = nz // 2
tt_slice = solver.traveltime.values[:, :, mid_k].T  # transpose so orientation matches x-y
im = ax2.imshow(tt_slice, origin='lower',
                extent=(xs.min(), xs.max(), ys.min(), ys.max()),
                aspect='auto')
ax2.set_title(f'Travel-time slice at z-index {mid_k}')
ax2.set_xlabel('x'); ax2.set_ylabel('y')
fig.colorbar(im, ax=ax2, label='Travel time (s)')
plt.tight_layout()
plt.show()

# ---------------------------
# 2) 3D voxel plot of velocity model + 2D mid-slice of velocity
# ---------------------------
# occupancy mask (show all voxels)
occupancy = np.ones((nx, ny, nz), dtype=bool)

# map velocities to facecolors via a cmap
vel_min, vel_max = solver.velocity.values.min(), solver.velocity.values.max()
norm_vel = plt.Normalize(vmin=vel_min, vmax=vel_max)
facecolors = cm.viridis(norm_vel(solver.velocity.values))

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(121, projection='3d')
ax.set_title('3D velocity voxels')

# matplotlib voxels expects boolean occupancy and facecolors shaped (nx,ny,nz,4)
ax.voxels(occupancy, facecolors=facecolors, edgecolor='k', linewidth=0.2, alpha=0.9)
ax.set_xlabel('x-index'); ax.set_ylabel('y-index'); ax.set_zlabel('z-index')

# colorbar for velocity (create a ScalarMappable)
mappable_v = cm.ScalarMappable(cmap='viridis', norm=norm_vel)
mappable_v.set_array(solver.velocity.values)
ax.invert_zaxis()

fig.colorbar(mappable_v, ax=ax, shrink=0.6, fraction=0.05, label='Velocity')




try:
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.plot(ray[:, 0], ray[:, 1], -ray[:, 2], '-', label='ray')
    ax.scatter([end_coord[0]], [end_coord[1]], [-end_coord[2]], c='r', label='end')
    ax.scatter([src_coord[0]], [src_coord[1]], [-src_coord[2]], c='k', label='source')
    ax.set_xlabel('x'); ax.set_ylabel('y'); ax.set_zlabel('z'); ax.legend()
    plt.title('Ray path')
    plt.show()
except NameError:
    pass

# %%
"""
Robust ray tracing script for PyKonal.
Creates a new solver per source to avoid version-dependent reset issues.
"""

import os
import numpy as np
import pykonal
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401

# --- Compatibility patch for NumPy >= 2.0 (fixes PyKonal bug) ---
if not hasattr(np, "infty"):
    np.infty = np.inf

# ---------- Grid / velocity setup helper ----------
def build_solver():
    solver = pykonal.EikonalSolver(coord_sys="cartesian")

    # grid geometry
    solver.velocity.min_coords = (0.0, 0.0, 0.0)
    solver.velocity.node_intervals = (1.0, 1.0, 1.0)
    solver.velocity.npts = (10, 10, 10)

    # velocity model
    nx, ny, nz = solver.velocity.npts
    vel = np.empty((nx, ny, nz), dtype=float)
    vel[:, :, 0] = 5.5
    vel[:, :, 1:] = 5.76
    solver.velocity.values = vel

    return solver

# ---------- Utility: check point inside domain ----------
def point_inside_domain(pt, solver):
    minc = np.array(solver.velocity.min_coords, dtype=float)
    intervals = np.array(solver.velocity.node_intervals, dtype=float)
    npts = np.array(solver.velocity.npts, dtype=int)
    maxc = minc + (npts - 1) * intervals
    return np.all(pt >= minc - 1e-8) and np.all(pt <= maxc + 1e-8)

# ---------- Main tracing function (rebuild solver per source) ----------
def trace_rays(sources, receivers, out_dir="rays_output", pairwise_if_same_length=True):
    """
    For robustness across PyKonal versions we build a fresh solver for each source.
    """
    os.makedirs(out_dir, exist_ok=True)

    Ns = sources.shape[0]
    Nr = receivers.shape[0]

    if Ns == Nr and pairwise_if_same_length:
        pairs = [(i, i) for i in range(Ns)]
        info_text = f"Pairwise mode (Ns==Nr=={Ns})"
    else:
        pairs = [(i, j) for i in range(Ns) for j in range(Nr)]
        info_text = f"All-pairs mode (Ns={Ns}, Nr={Nr}, total_pairs={len(pairs)})"

    print(f"[trace_rays] {info_text}")

    all_rays = []
    failed = []

    # We'll build a prototype solver only to get domain info (min_coords, intervals, npts)
    proto = build_solver()
    min_coords = np.array(proto.velocity.min_coords)
    intervals = np.array(proto.velocity.node_intervals)
    npts = proto.velocity.npts

    for src_i, rec_j in pairs:
        src = np.asarray(sources[src_i], dtype=float)
        rec = np.asarray(receivers[rec_j], dtype=float)

        # bounds check (using prototype solver)
        if not point_inside_domain(src, proto):
            msg = f"Source {src_i} at {src} is outside domain; skipping."
            print(msg)
            failed.append(("src", src_i, rec_j, msg))
            continue
        if not point_inside_domain(rec, proto):
            msg = f"Receiver {rec_j} at {rec} is outside domain; skipping."
            print(msg)
            failed.append(("rec", src_i, rec_j, msg))
            continue

        # build fresh solver for this source
        solver = build_solver()

        # choose nearest grid node for the source
        rel = (src - min_coords) / intervals
        src_idx = tuple(np.round(rel).astype(int).tolist())
        src_idx = (
            max(0, min(npts[0] - 1, src_idx[0])),
            max(0, min(npts[1] - 1, src_idx[1])),
            max(0, min(npts[2] - 1, src_idx[2])),
        )

        # initialize source node
        try:
            solver.traveltime.values[src_idx] = 0.0
        except Exception as e:
            msg = f"Failed to set traveltime.values at {src_idx}: {e}"
            print(msg)
            failed.append(("init_tt", src_i, rec_j, msg))
            continue


        pushed = False
        try:
            # preferred approach if solver exposes 'unknown' at top-level
            solver.unknown[src_idx] = False
            try:
                solver.trial.push(*src_idx)
                pushed = True
            except Exception:
                pass
        except Exception:
            # fallback to traveltime flags
            try:
                solver.traveltime.known[src_idx] = True
                solver.traveltime.unknown[src_idx] = False
                try:
                    solver.traveltime.trial.push(*src_idx)
                    pushed = True
                except Exception:
                    pass
            except Exception:
                # last-ditch: try pushing to solver.trial if exists
                try:
                    solver.trial.push(*src_idx)
                    pushed = True
                except Exception:

                    pushed = False

        # solve the eikonal
        try:
            solver.solve()
        except Exception as e:
            msg = f"Solver failed for source {src_i} (idx={src_idx}): {e}"
            print(msg)
            failed.append(("solve", src_i, rec_j, msg))
            continue

        # trace ray from receiver back to source
        try:
            ray = solver.trace_ray(rec)
            if ray is None or len(ray) == 0:
                raise RuntimeError("trace_ray returned empty path")
        except Exception as e:
            msg = f"trace_ray failed for src {src_i} -> rec {rec_j}: {e}"
            print(msg)
            failed.append(("trace", src_i, rec_j, msg))
            continue

        # save ray
        fname = os.path.join(out_dir, f"ray_src{src_i}_rec{rec_j}.npy")
        np.save(fname, ray)
        print(f"Saved ray for src{src_i}->rec{rec_j} to {fname}; path length {len(ray)}")
        all_rays.append((src_i, rec_j, ray))

    print(f"[trace_rays] Done. rays_saved={len(all_rays)}, failures={len(failed)}")
    return all_rays, failed

# ---------- Example usage block ----------
if __name__ == "__main__":
    sources = np.load("/content/cartesian_src_SOLA.npy")      # shape (Ns,3)
    receivers = np.load("/content/cartesian_rec_SOLA.npy")  # shape (Nr,3)

    if sources.ndim != 2 or sources.shape[1] != 3:
        raise ValueError("sources.npy should be shape (Ns,3)")
    if receivers.ndim != 2 or receivers.shape[1] != 3:
        raise ValueError("receivers.npy should be shape (Nr,3)")

    rays, failures = trace_rays(sources, receivers, out_dir="rays_output")

    # plotting (same as before)
    fig = plt.figure(figsize=(10, 8))
    ax = fig.add_subplot(111, projection="3d")
    for (s_i, r_j, ray) in rays:
        ax.plot(ray[:, 0], ray[:, 1], ray[:, 2], linewidth=1.5, label=f"s{s_i}-r{r_j}")
        ax.scatter([ray[0, 0]], [ray[0, 1]], [ray[0, 2]], marker="o", s=30)
        ax.scatter([ray[-1, 0]], [ray[-1, 1]], [ray[-1, 2]], marker="^", s=40)

    ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
    ax.set_title("Traced rays (receiver -> source)")
    if len(rays) <= 20:
        ax.legend()
    plt.tight_layout()
    plt.show()

    if failures:
        print("\nFailures:")
        for f in failures:
            print(f)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Saved ray for src214->rec13 to rays_output/ray_src214_rec13.npy; path length 20
# Saved ray for src214->rec14 to rays_output/ray_src214_rec14.npy; path length 20
# Saved ray for src214->rec15 to rays_output/ray_src214_rec15.npy; path length 18
# Saved ray for src214->rec16 to rays_output/ray_src214_rec16.npy; path length 18
# Saved ray for src214->rec17 to rays_output/ray_src214_rec17.npy; path length 18
# Saved ray for src214->rec18 to rays_output/ray_src214_rec18.npy; path length 18
# Saved ray for src214->rec19 to rays_output/ray_src214_rec19.npy; path length 19
# Saved ray for src214->rec20 to rays_output/ray_src214_rec20.npy; path length 19
# Saved ray for src214->rec21 to rays_output/ray_src214_rec21.npy; path length 18
# Saved ray for src214->rec22 to rays_output/ray_src214_rec22.npy; path length 17
# Saved ray for src214->rec23 to rays_output/ray_src214_rec23.npy; path length 17
# Saved ray for src214->rec24 to rays_output/ray_src214_rec24.npy; path length 17
# Saved ray for src214->rec25 to rays_output/ray_src214_rec25.npy; path length 17
# Saved ray for src214->rec26 to rays_output/ray_src214_rec26.npy; path length 18
# Saved ray for src214->rec27 to rays_output/ray_src214_rec27.npy; path length 18
# Saved ray for src214->rec28 to rays_output/ray_src214_rec28.npy; path length 18
# Saved ray for src214->rec29 to rays_output/ray_src214_rec29.npy; path length 18
# Saved ray for src214->rec30 to rays_output/ray_src214_rec30.npy; path length 18
# Saved ray for src214->rec31 to rays_output/ray_src214_rec31.npy; path length 18
# Saved ray for src214->rec32 to rays_output/ray_src214_rec32.npy; path length 18
# Saved ray for src214->rec33 to rays_output/ray_src214_rec33.npy; path length 18
# Saved ray for src214->rec34 to rays_output/ray_src214_rec34.npy; path length 18
# Saved ray for src214->rec35 to rays_output/ray_src214_rec35.npy; path length 17
# Saved ray for src214->rec36 to rays_output/ray_src214_rec36.npy; path length 17
# Saved ray for src214->rec37 to rays_output/ray_src214_rec37.npy; path length 17
# Saved ray for src214->rec38 to rays_output/ray_src214_rec38.npy; path length 17
# Saved ray for src214->rec39 to rays_output/ray_src214_rec39.npy; path length 17
# Saved ray for src214->rec40 to rays_output/ray_src214_rec40.npy; path length 18
# Saved ray for src214->rec41 to rays_output/ray_src214_rec41.npy; path length 18
# Saved ray for src214->rec42 to rays_output/ray_src214_rec42.npy; path length 18
# Saved ray for src214->rec43 to rays_output/ray_src214_rec43.npy; path length 18
# Saved ray for src214->rec44 to rays_output/ray_src214_rec44.npy; path length 18
# Saved ray for src214->rec45 to rays_output/ray_src214_rec45.npy; path length 20
# Saved ray for src214->rec46 to rays_output/ray_src214_rec46.npy; path length 19
# Saved ray for src214->rec47 to rays_output/ray_src214_rec47.npy; path length 16
# Saved ray for src214->rec48 to rays_output/ray_src214_rec48.npy; path length 16
# Saved ray for src214->rec49 to rays_output/ray_src214_rec49.npy; path length 17
# Saved ray for src214->rec50 to rays_output/ray_src214_rec50.npy; path length 17
# Saved ray for src214->rec51 to rays_output/ray_src214_rec51.npy; path length 17
# Saved ray for src214->rec52 to rays_output/ray_src214_rec52.npy; path length 17
# Saved ray for src214->rec53 to rays_output/ray_src214_rec53.npy; path length 17
# Saved ray for src214->rec54 to rays_output/ray_src214_rec54.npy; path length 17
# Saved ray for src214->rec55 to rays_output/ray_src214_rec55.npy; path length 17
# Saved ray for src214->rec56 to rays_output/ray_src214_rec56.npy; path length 17
# Saved ray for src214->rec57 to rays_output/ray_src214_rec57.npy; path length 16
# Saved ray for src214->rec58 to rays_output/ray_src214_rec58.npy; path length 16
# Saved ray for src214->rec59 to rays_output/ray_src214_rec59.npy; path length 16
# Saved ray for src214->rec60 to rays_output/ray_src214_rec60.npy; path length 17
# Saved ray for src214->rec61 to rays_output/ray_src214_rec61.npy; path length 16
# Saved ray for src214->rec62 to rays_output/ray_src214_rec62.npy; path length 17
# Saved ray for src214->rec63 to rays_output/ray_src214_rec63.npy; path length 21
# Saved ray for src214->rec64 to rays_output/ray_src214_rec64.npy; path length 21
# Saved ray for src214->rec65 to rays_output/ray_src214_rec65.npy; path length 22
# Saved ray for src214->rec66 to rays_output/ray_src214_rec66.npy; path length 22
# Saved ray for src214->rec67 to rays_output/ray_src214_rec67.npy; path length 23
# Saved ray for src214->rec68 to rays_output/ray_src214_rec68.npy; path length 22
# Saved ray for src214->rec69 to rays_output/ray_src214_rec69.npy; path length 23
# Saved ray for src214->rec70 to rays_output/ray_src214_rec70.npy; path length 22
# Saved ray for src214->rec71 to rays_output/ray_src214_rec71.npy; path length 21
# Saved ray for src214->rec72 to rays_output/ray_src214_rec72.npy; path length 20
# Saved ray for src214->rec73 to rays_output/ray_src214_rec73.npy; path length 21
# Saved ray for src214->rec74 to rays_output/ray_src214_rec74.npy; path length 24
# Saved ray for src214->rec75 to rays_output/ray_src214_rec75.npy; path length 19
# Saved ray for src214->rec76 to rays_output/ray_src214_rec76.npy; path length 20
# Saved ray for src214->rec77 to rays_output/ray_src214_rec77.npy; path length 20
# Saved ray for src214->rec78 to rays_output/ray_src214_rec78.npy; path length 21
# Saved ray for src214->rec79 to rays_output/ray_src214_rec79.npy; path length 21
# Saved ray for src214->rec80 to rays_output/ray_src214_rec80.npy; path length 21
# Saved ray for src214->rec81 to rays_output/ray_src214_rec81.npy; path length 20
# Saved ray for src214->rec82 to rays_output/ray_src214_rec82.npy; path length 19
# Saved ray for src214->rec83 to rays_output/ray_src214_rec83.npy; path length 18
# Saved ray for src214->rec84 to rays_output/ray_src214_rec84.npy; path length 19
# Saved ray for src214->rec85 to rays_output/ray_src214_rec85.npy; path length 19
# Saved ray for src214->rec86 to rays_output/ray_src214_rec86.npy; path length 21
# Saved ray for src214->rec87 to rays_output/ray_src214_rec87.npy; path length 22
# Saved ray for src214->rec88 to rays_output/ray_src214_rec88.npy; path length 21
# Saved ray for src214->rec89 to rays_output/ray_src214_rec89.npy; path length 20
# Saved ray for src214->rec90 to rays_output/ray_src214_rec90.npy; path length 18
# Saved ray for src214->rec91 to rays_output/ray_src214_rec91.npy; path length 18
# Saved ray for src214->rec92 to rays_output/ray_src214_rec92.npy; path length 18
# Saved ray for src214->rec93 to rays_output/ray_src214_rec93.npy; path length 19
# Saved ray for src214->rec94 to rays_output/ray_src214_rec94.npy; path length 19
# Saved ray for src214->rec95 to rays_output/ray_src214_rec95.npy; path length 20
# Saved ray for src214->rec96 to rays_output/ray_src214_rec96.npy; path length 20
# Saved ray for src214->rec97 to rays_output/ray_src214_rec97.npy; path length 19
# Saved ray for src214->rec98 to rays_output/ray_src214_rec98.npy; path length 19
# Saved ray for src214->rec99 to rays_output/ray_src214_rec99.npy; path length 18
# Saved ray for src214->rec100 to rays_output/ray_src214_rec100.npy; path length 18
# Saved ray for src214->rec101 to rays_output/ray_src214_rec101.npy; path length 18
# Saved ray for src214->rec102 to rays_output/ray_src214_rec102.npy; path length 19
# Saved ray for src214->rec103 to rays_output/ray_src214_rec103.npy; path length 19
# Saved ray for src214->rec104 to rays_output/ray_src214_rec104.npy; path length 18
# Saved ray for src214->rec105 to rays_output/ray_src214_rec105.npy; path length 18
# Saved ray for src214->rec106 to rays_output/ray_src214_rec106.npy; path length 18
# Saved ray for src214->rec107 to rays_output/ray_src214_rec107.npy; path length 19
# Saved ray for src214->rec108 to rays_output/ray_src214_rec108.npy; path length 19
# Saved ray for src214->rec109 to rays_output/ray_src214_rec109.npy; path length 20
# Saved ray for src214->rec110 to rays_output/ray_src214_rec110.npy; path length 20
# Saved ray for src214->rec111 to rays_output/ray_src214_rec111.npy; path length 19
# Saved ray for src214->rec112 to rays_output/ray_src214_rec112.npy; path length 19
# Saved ray for src214->rec113 to rays_output/ray_src214_rec113.npy; path length 18
# Saved ray for src214->rec114 to rays_output/ray_src214_rec114.npy; path length 18
# Saved ray for src214->rec115 to rays_output/ray_src214_rec115.npy; path length 18
# Saved ray for src214->rec116 to rays_output/ray_src214_rec116.npy; path length 19
# Saved ray for src214->rec117 to rays_output/ray_src214_rec117.npy; path length 19
# Saved ray for src214->rec118 to rays_output/ray_src214_rec118.npy; path length 18
# Saved ray for src214->rec119 to rays_output/ray_src214_rec119.npy; path length 18
# Saved ray for src214->rec120 to rays_output/ray_src214_rec120.npy; path length 18
# Saved ray for src214->rec121 to rays_output/ray_src214_rec121.npy; path length 19
# Saved ray for src214->rec122 to rays_output/ray_src214_rec122.npy; path length 19
# Saved ray for src214->rec123 to rays_output/ray_src214_rec123.npy; path length 19
# Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.
# Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.
# Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.
# Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.
# Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.
# Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.
# Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.
# Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.
# Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.
# Saved ray for src214->rec133 to rays_output/ray_src214_rec133.npy; path length 21
# Saved ray for src214->rec134 to rays_output/ray_src214_rec134.npy; path length 21
# Saved ray for src214->rec135 to rays_output/ray_src214_rec135.npy; path length 20
# Saved ray for src214->rec136 to rays_output/ray_src214_rec136.npy; path length 17
# Saved ray for src214->rec137 to rays_output/ray_src214_rec137.npy; path length 17
# Saved ray for src214->rec138 to rays_output/ray_src214_rec138.npy; path length 18
# Saved ray for src214->rec139 to rays_output/ray_src214_rec139.npy; path length 18
# Saved ray for src214->rec140 to rays_output/ray_src214_rec140.npy; path length 17
# Saved ray for src214->rec141 to rays_output/ray_src214_rec141.npy; path length 17
# Saved ray for src214->rec142 to rays_output/ray_src214_rec142.npy; path length 17
# Saved ray for src214->rec143 to rays_output/ray_src214_rec143.npy; path length 17
# Saved ray for src214->rec144 to rays_output/ray_src214_rec144.npy; path length 17
# Saved ray for src214->rec145 to rays_output/ray_src214_rec145.npy; path length 17
# Saved ray for src214->rec146 to rays_output/ray_src214_rec146.npy; path length 17
# Saved ray for src214->rec147 to rays_output/ray_src214_rec147.npy; path length 17
# Saved ray for src214->rec148 to rays_output/ray_src214_rec148.npy; path length 17
# Saved ray for src214->rec149 to rays_output/ray_src214_rec149.npy; path length 17
# Saved ray for src214->rec150 to rays_output/ray_src214_rec150.npy; path length 17
# Saved ray for src214->rec151 to rays_output/ray_src214_rec151.npy; path length 17
# Saved ray for src214->rec152 to rays_output/ray_src214_rec152.npy; path length 17
# Saved ray for src214->rec153 to rays_output/ray_src214_rec153.npy; path length 17
# Saved ray for src214->rec154 to rays_output/ray_src214_rec154.npy; path length 17
# Saved ray for src214->rec155 to rays_output/ray_src214_rec155.npy; path length 18
# Saved ray for src214->rec156 to rays_output/ray_src214_rec156.npy; path length 18
# Saved ray for src214->rec157 to rays_output/ray_src214_rec157.npy; path length 19
# Saved ray for src214->rec158 to rays_output/ray_src214_rec158.npy; path length 19
# Saved ray for src214->rec159 to rays_output/ray_src214_rec159.npy; path length 18
# Saved ray for src214->rec160 to rays_output/ray_src214_rec160.npy; path length 18
# Saved ray for src214->rec161 to rays_output/ray_src214_rec161.npy; path length 17
# Saved ray for src214->rec162 to rays_output/ray_src214_rec162.npy; path length 18
# Saved ray for src214->rec163 to rays_output/ray_src214_rec163.npy; path length 17
# Saved ray for src214->rec164 to rays_output/ray_src214_rec164.npy; path length 19
# Saved ray for src214->rec165 to rays_output/ray_src214_rec165.npy; path length 19
# Saved ray for src214->rec166 to rays_output/ray_src214_rec166.npy; path length 20
# Saved ray for src214->rec167 to rays_output/ray_src214_rec167.npy; path length 24
# Saved ray for src214->rec168 to rays_output/ray_src214_rec168.npy; path length 20
# Saved ray for src214->rec169 to rays_output/ray_src214_rec169.npy; path length 20
# Saved ray for src214->rec170 to rays_output/ray_src214_rec170.npy; path length 20
# Saved ray for src214->rec171 to rays_output/ray_src214_rec171.npy; path length 20
# Saved ray for src214->rec172 to rays_output/ray_src214_rec172.npy; path length 20
# Saved ray for src214->rec173 to rays_output/ray_src214_rec173.npy; path length 20
# Saved ray for src214->rec174 to rays_output/ray_src214_rec174.npy; path length 23
# Saved ray for src214->rec175 to rays_output/ray_src214_rec175.npy; path length 23
# Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.
# Saved ray for src214->rec177 to rays_output/ray_src214_rec177.npy; path length 18
# Saved ray for src214->rec178 to rays_output/ray_src214_rec178.npy; path length 21
# Saved ray for src215->rec0 to rays_output/ray_src215_rec0.npy; path length 23
# Saved ray for src215->rec1 to rays_output/ray_src215_rec1.npy; path length 22
# Saved ray for src215->rec2 to rays_output/ray_src215_rec2.npy; path length 23
# Saved ray for src215->rec3 to rays_output/ray_src215_rec3.npy; path length 21
# Saved ray for src215->rec4 to rays_output/ray_src215_rec4.npy; path length 21
# Saved ray for src215->rec5 to rays_output/ray_src215_rec5.npy; path length 20
# Saved ray for src215->rec6 to rays_output/ray_src215_rec6.npy; path length 20
# Saved ray for src215->rec7 to rays_output/ray_src215_rec7.npy; path length 20
# Saved ray for src215->rec8 to rays_output/ray_src215_rec8.npy; path length 19
# Saved ray for src215->rec9 to rays_output/ray_src215_rec9.npy; path length 20
# Saved ray for src215->rec10 to rays_output/ray_src215_rec10.npy; path length 21
# Saved ray for src215->rec11 to rays_output/ray_src215_rec11.npy; path length 21
# Saved ray for src215->rec12 to rays_output/ray_src215_rec12.npy; path length 20
# Saved ray for src215->rec13 to rays_output/ray_src215_rec13.npy; path length 20
# Saved ray for src215->rec14 to rays_output/ray_src215_rec14.npy; path length 20
# Saved ray for src215->rec15 to rays_output/ray_src215_rec15.npy; path length 18
# Saved ray for src215->rec16 to rays_output/ray_src215_rec16.npy; path length 18
# Saved ray for src215->rec17 to rays_output/ray_src215_rec17.npy; path length 18
# Saved ray for src215->rec18 to rays_output/ray_src215_rec18.npy; path length 18
# Saved ray for src215->rec19 to rays_output/ray_src215_rec19.npy; path length 19
# Saved ray for src215->rec20 to rays_output/ray_src215_rec20.npy; path length 19
# Saved ray for src215->rec21 to rays_output/ray_src215_rec21.npy; path length 18
# Saved ray for src215->rec22 to rays_output/ray_src215_rec22.npy; path length 17
# Saved ray for src215->rec23 to rays_output/ray_src215_rec23.npy; path length 17
# Saved ray for src215->rec24 to rays_output/ray_src215_rec24.npy; path length 17
# Saved ray for src215->rec25 to rays_output/ray_src215_rec25.npy; path length 17
# Saved ray for src215->rec26 to rays_output/ray_src215_rec26.npy; path length 18
# Saved ray for src215->rec27 to rays_output/ray_src215_rec27.npy; path length 18
# Saved ray for src215->rec28 to rays_output/ray_src215_rec28.npy; path length 18
# Saved ray for src215->rec29 to rays_output/ray_src215_rec29.npy; path length 18
# Saved ray for src215->rec30 to rays_output/ray_src215_rec30.npy; path length 18
# Saved ray for src215->rec31 to rays_output/ray_src215_rec31.npy; path length 18
# Saved ray for src215->rec32 to rays_output/ray_src215_rec32.npy; path length 18
# Saved ray for src215->rec33 to rays_output/ray_src215_rec33.npy; path length 18
# Saved ray for src215->rec34 to rays_output/ray_src215_rec34.npy; path length 18
# Saved ray for src215->rec35 to rays_output/ray_src215_rec35.npy; path length 17
# Saved ray for src215->rec36 to rays_output/ray_src215_rec36.npy; path length 17
# Saved ray for src215->rec37 to rays_output/ray_src215_rec37.npy; path length 17
# Saved ray for src215->rec38 to rays_output/ray_src215_rec38.npy; path length 17
# Saved ray for src215->rec39 to rays_output/ray_src215_rec39.npy; path length 17
# Saved ray for src215->rec40 to rays_output/ray_src215_rec40.npy; path length 18
# Saved ray for src215->rec41 to rays_output/ray_src215_rec41.npy; path length 18
# Saved ray for src215->rec42 to rays_output/ray_src215_rec42.npy; path length 18
# Saved ray for src215->rec43 to rays_output/ray_src215_rec43.npy; path length 18
# Saved ray for src215->rec44 to rays_output/ray_src215_rec44.npy; path length 18
# Saved ray for src215->rec45 to rays_output/ray_src215_rec45.npy; path length 20
# Saved ray for src215->rec46 to rays_output/ray_src215_rec46.npy; path length 19
# Saved ray for src215->rec47 to rays_output/ray_src215_rec47.npy; path length 16
# Saved ray for src215->rec48 to rays_output/ray_src215_rec48.npy; path length 16
# Saved ray for src215->rec49 to rays_output/ray_src215_rec49.npy; path length 17
# Saved ray for src215->rec50 to rays_output/ray_src215_rec50.npy; path length 17
# Saved ray for src215->rec51 to rays_output/ray_src215_rec51.npy; path length 17
# Saved ray for src215->rec52 to rays_output/ray_src215_rec52.npy; path length 17
# Saved ray for src215->rec53 to rays_output/ray_src215_rec53.npy; path length 17
# Saved ray for src215->rec54 to rays_output/ray_src215_rec54.npy; path length 17
# Saved ray for src215->rec55 to rays_output/ray_src215_rec55.npy; path length 17
# Saved ray for src215->rec56 to rays_output/ray_src215_rec56.npy; path length 17
# Saved ray for src215->rec57 to rays_output/ray_src215_rec57.npy; path length 16
# Saved ray for src215->rec58 to rays_output/ray_src215_rec58.npy; path length 16
# Saved ray for src215->rec59 to rays_output/ray_src215_rec59.npy; path length 16
# Saved ray for src215->rec60 to rays_output/ray_src215_rec60.npy; path length 17
# Saved ray for src215->rec61 to rays_output/ray_src215_rec61.npy; path length 16
# Saved ray for src215->rec62 to rays_output/ray_src215_rec62.npy; path length 17
# Saved ray for src215->rec63 to rays_output/ray_src215_rec63.npy; path length 21
# Saved ray for src215->rec64 to rays_output/ray_src215_rec64.npy; path length 21
# Saved ray for src215->rec65 to rays_output/ray_src215_rec65.npy; path length 22
# Saved ray for src215->rec66 to rays_output/ray_src215_rec66.npy; path length 22
# Saved ray for src215->rec67 to rays_output/ray_src215_rec67.npy; path length 23
# Saved ray for src215->rec68 to rays_output/ray_src215_rec68.npy; path length 22
# Saved ray for src215->rec69 to rays_output/ray_src215_rec69.npy; path length 23
# Saved ray for src215->rec70 to rays_output/ray_src215_rec70.npy; path length 22
# Saved ray for src215->rec71 to rays_output/ray_src215_rec71.npy; path length 21
# Saved ray for src215->rec72 to rays_output/ray_src215_rec72.npy; path length 20
# Saved ray for src215->rec73 to rays_output/ray_src215_rec73.npy; path length 21
# Saved ray for src215->rec74 to rays_output/ray_src215_rec74.npy; path length 24
# Saved ray for src215->rec75 to rays_output/ray_src215_rec75.npy; path length 19
# Saved ray for src215->rec76 to rays_output/ray_src215_rec76.npy; path length 20
# Saved ray for src215->rec77 to rays_output/ray_src215_rec77.npy; path length 20
# Saved ray for src215->rec78 to rays_output/ray_src215_rec78.npy; path length 21
# Saved ray for src215->rec79 to rays_output/ray_src215_rec79.npy; path length 21
# Saved ray for src215->rec80 to rays_output/ray_src215_rec80.npy; path length 21
# Saved ray for src215->rec81 to rays_output/ray_src215_rec81.npy; path length 20
# Saved ray for src215->rec82 to rays_output/ray_src215_rec82.npy; path length 19
# Saved ray for src215->rec83 to rays_output/ray_src215_rec83.npy; path length 18
# Saved ray for src215->rec84 to rays_output/ray_src215_rec84.npy; path length 19
# Saved ray for src215->rec85 to rays_output/ray_src215_rec85.npy; path length 19
# Saved ray for src215->rec86 to rays_output/ray_src215_rec86.npy; path length 21
# Saved ray for src215->rec87 to rays_output/ray_src215_rec87.npy; path length 22
# Saved ray for src215->rec88 to rays_output/ray_src215_rec88.npy; path length 21
# Saved ray for src215->rec89 to rays_output/ray_src215_rec89.npy; path length 20
# Saved ray for src215->rec90 to rays_output/ray_src215_rec90.npy; path length 18
# Saved ray for src215->rec91 to rays_output/ray_src215_rec91.npy; path length 18
# Saved ray for src215->rec92 to rays_output/ray_src215_rec92.npy; path length 18
# Saved ray for src215->rec93 to rays_output/ray_src215_rec93.npy; path length 19
# Saved ray for src215->rec94 to rays_output/ray_src215_rec94.npy; path length 19
# Saved ray for src215->rec95 to rays_output/ray_src215_rec95.npy; path length 20
# Saved ray for src215->rec96 to rays_output/ray_src215_rec96.npy; path length 20
# Saved ray for src215->rec97 to rays_output/ray_src215_rec97.npy; path length 19
# Saved ray for src215->rec98 to rays_output/ray_src215_rec98.npy; path length 19
# Saved ray for src215->rec99 to rays_output/ray_src215_rec99.npy; path length 18
# Saved ray for src215->rec100 to rays_output/ray_src215_rec100.npy; path length 18
# Saved ray for src215->rec101 to rays_output/ray_src215_rec101.npy; path length 18
# Saved ray for src215->rec102 to rays_output/ray_src215_rec102.npy; path length 19
# Saved ray for src215->rec103 to rays_output/ray_src215_rec103.npy; path length 19
# Saved ray for src215->rec104 to rays_output/ray_src215_rec104.npy; path length 18
# Saved ray for src215->rec105 to rays_output/ray_src215_rec105.npy; path length 18
# Saved ray for src215->rec106 to rays_output/ray_src215_rec106.npy; path length 18
# Saved ray for src215->rec107 to rays_output/ray_src215_rec107.npy; path length 19
# Saved ray for src215->rec108 to rays_output/ray_src215_rec108.npy; path length 19
# Saved ray for src215->rec109 to rays_output/ray_src215_rec109.npy; path length 20
# Saved ray for src215->rec110 to rays_output/ray_src215_rec110.npy; path length 20
# Saved ray for src215->rec111 to rays_output/ray_src215_rec111.npy; path length 19
# Saved ray for src215->rec112 to rays_output/ray_src215_rec112.npy; path length 19
# Saved ray for src215->rec113 to rays_output/ray_src215_rec113.npy; path length 18
# Saved ray for src215->rec114 to rays_output/ray_src215_rec114.npy; path length 18
# Saved ray for src215->rec115 to rays_output/ray_src215_rec115.npy; path length 18
# Saved ray for src215->rec116 to rays_output/ray_src215_rec116.npy; path length 19
# Saved ray for src215->rec117 to rays_output/ray_src215_rec117.npy; path length 19
# Saved ray for src215->rec118 to rays_output/ray_src215_rec118.npy; path length 18
# Saved ray for src215->rec119 to rays_output/ray_src215_rec119.npy; path length 18
# Saved ray for src215->rec120 to rays_output/ray_src215_rec120.npy; path length 18
# Saved ray for src215->rec121 to rays_output/ray_src215_rec121.npy; path length 19
# Saved ray for src215->rec122 to rays_output/ray_src215_rec122.npy; path length 19
# Saved ray for src215->rec123 to rays_output/ray_src215_rec123.npy; path length 19
# Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.
# Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.
# Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.
# Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.
# Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.
# Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.
# Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.
# Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.
# Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.
# Saved ray for src215->rec133 to rays_output/ray_src215_rec133.npy; path length 21
# Saved ray for src215->rec134 to rays_output/ray_src215_rec134.npy; path length 21
# Saved ray for src215->rec135 to rays_output/ray_src215_rec135.npy; path length 20
# Saved ray for src215->rec136 to rays_output/ray_src215_rec136.npy; path length 17
# Saved ray for src215->rec137 to rays_output/ray_src215_rec137.npy; path length 17
# Saved ray for src215->rec138 to rays_output/ray_src215_rec138.npy; path length 18
# Saved ray for src215->rec139 to rays_output/ray_src215_rec139.npy; path length 18
# Saved ray for src215->rec140 to rays_output/ray_src215_rec140.npy; path length 17
# Saved ray for src215->rec141 to rays_output/ray_src215_rec141.npy; path length 17
# Saved ray for src215->rec142 to rays_output/ray_src215_rec142.npy; path length 17
# Saved ray for src215->rec143 to rays_output/ray_src215_rec143.npy; path length 17
# Saved ray for src215->rec144 to rays_output/ray_src215_rec144.npy; path length 17
# Saved ray for src215->rec145 to rays_output/ray_src215_rec145.npy; path length 17
# Saved ray for src215->rec146 to rays_output/ray_src215_rec146.npy; path length 17
# Saved ray for src215->rec147 to rays_output/ray_src215_rec147.npy; path length 17
# Saved ray for src215->rec148 to rays_output/ray_src215_rec148.npy; path length 17
# Saved ray for src215->rec149 to rays_output/ray_src215_rec149.npy; path length 17
# Saved ray for src215->rec150 to rays_output/ray_src215_rec150.npy; path length 17
# Saved ray for src215->rec151 to rays_output/ray_src215_rec151.npy; path length 17
# Saved ray for src215->rec152 to rays_output/ray_src215_rec152.npy; path length 17
# Saved ray for src215->rec153 to rays_output/ray_src215_rec153.npy; path length 17
# Saved ray for src215->rec154 to rays_output/ray_src215_rec154.npy; path length 17
# Saved ray for src215->rec155 to rays_output/ray_src215_rec155.npy; path length 18
# Saved ray for src215->rec156 to rays_output/ray_src215_rec156.npy; path length 18
# Saved ray for src215->rec157 to rays_output/ray_src215_rec157.npy; path length 19
# Saved ray for src215->rec158 to rays_output/ray_src215_rec158.npy; path length 19
# Saved ray for src215->rec159 to rays_output/ray_src215_rec159.npy; path length 18
# Saved ray for src215->rec160 to rays_output/ray_src215_rec160.npy; path length 18
# Saved ray for src215->rec161 to rays_output/ray_src215_rec161.npy; path length 17
# Saved ray for src215->rec162 to rays_output/ray_src215_rec162.npy; path length 18
# Saved ray for src215->rec163 to rays_output/ray_src215_rec163.npy; path length 17
# Saved ray for src215->rec164 to rays_output/ray_src215_rec164.npy; path length 19
# Saved ray for src215->rec165 to rays_output/ray_src215_rec165.npy; path length 19
# Saved ray for src215->rec166 to rays_output/ray_src215_rec166.npy; path length 20
# Saved ray for src215->rec167 to rays_output/ray_src215_rec167.npy; path length 24
# Saved ray for src215->rec168 to rays_output/ray_src215_rec168.npy; path length 20
# Saved ray for src215->rec169 to rays_output/ray_src215_rec169.npy; path length 20
# Saved ray for src215->rec170 to rays_output/ray_src215_rec170.npy; path length 20
# Saved ray for src215->rec171 to rays_output/ray_src215_rec171.npy; path length 20
# Saved ray for src215->rec172 to rays_output/ray_src215_rec172.npy; path length 20
# Saved ray for src215->rec173 to rays_output/ray_src215_rec173.npy; path length 20
# Saved ray for src215->rec174 to rays_output/ray_src215_rec174.npy; path length 23
# Saved ray for src215->rec175 to rays_output/ray_src215_rec175.npy; path length 23
# Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.
# Saved ray for src215->rec177 to rays_output/ray_src215_rec177.npy; path length 18
# Saved ray for src215->rec178 to rays_output/ray_src215_rec178.npy; path length 21
# Saved ray for src216->rec0 to rays_output/ray_src216_rec0.npy; path length 23
# Saved ray for src216->rec1 to rays_output/ray_src216_rec1.npy; path length 22
# Saved ray for src216->rec2 to rays_output/ray_src216_rec2.npy; path length 23
# Saved ray for src216->rec3 to rays_output/ray_src216_rec3.npy; path length 21
# Saved ray for src216->rec4 to rays_output/ray_src216_rec4.npy; path length 21
# Saved ray for src216->rec5 to rays_output/ray_src216_rec5.npy; path length 20
# Saved ray for src216->rec6 to rays_output/ray_src216_rec6.npy; path length 20
# Saved ray for src216->rec7 to rays_output/ray_src216_rec7.npy; path length 20
# Saved ray for src216->rec8 to rays_output/ray_src216_rec8.npy; path length 19
# Saved ray for src216->rec9 to rays_output/ray_src216_rec9.npy; path length 20
# Saved ray for src216->rec10 to rays_output/ray_src216_rec10.npy; path length 21
# Saved ray for src216->rec11 to rays_output/ray_src216_rec11.npy; path length 21
# Saved ray for src216->rec12 to rays_output/ray_src216_rec12.npy; path length 20
# Saved ray for src216->rec13 to rays_output/ray_src216_rec13.npy; path length 20
# Saved ray for src216->rec14 to rays_output/ray_src216_rec14.npy; path length 20
# Saved ray for src216->rec15 to rays_output/ray_src216_rec15.npy; path length 18
# Saved ray for src216->rec16 to rays_output/ray_src216_rec16.npy; path length 18
# Saved ray for src216->rec17 to rays_output/ray_src216_rec17.npy; path length 18
# Saved ray for src216->rec18 to rays_output/ray_src216_rec18.npy; path length 18
# Saved ray for src216->rec19 to rays_output/ray_src216_rec19.npy; path length 19
# Saved ray for src216->rec20 to rays_output/ray_src216_rec20.npy; path length 19
# Saved ray for src216->rec21 to rays_output/ray_src216_rec21.npy; path length 18
# Saved ray for src216->rec22 to rays_output/ray_src216_rec22.npy; path length 17
# Saved ray for src216->rec23 to rays_output/ray_src216_rec23.npy; path length 17
# Saved ray for src216->rec24 to rays_output/ray_src216_rec24.npy; path length 17
# Saved ray for src216->rec25 to rays_output/ray_src216_rec25.npy; path length 17
# Saved ray for src216->rec26 to rays_output/ray_src216_rec26.npy; path length 18
# Saved ray for src216->rec27 to rays_output/ray_src216_rec27.npy; path length 18
# Saved ray for src216->rec28 to rays_output/ray_src216_rec28.npy; path length 18
# Saved ray for src216->rec29 to rays_output/ray_src216_rec29.npy; path length 18
# Saved ray for src216->rec30 to rays_output/ray_src216_rec30.npy; path length 18
# Saved ray for src216->rec31 to rays_output/ray_src216_rec31.npy; path length 18
# Saved ray for src216->rec32 to rays_output/ray_src216_rec32.npy; path length 18
# Saved ray for src216->rec33 to rays_output/ray_src216_rec33.npy; path length 18
# Saved ray for src216->rec34 to rays_output/ray_src216_rec34.npy; path length 18
# Saved ray for src216->rec35 to rays_output/ray_src216_rec35.npy; path length 17
# Saved ray for src216->rec36 to rays_output/ray_src216_rec36.npy; path length 17
# Saved ray for src216->rec37 to rays_output/ray_src216_rec37.npy; path length 17
# Saved ray for src216->rec38 to rays_output/ray_src216_rec38.npy; path length 17
# Saved ray for src216->rec39 to rays_output/ray_src216_rec39.npy; path length 17
# Saved ray for src216->rec40 to rays_output/ray_src216_rec40.npy; path length 18
# Saved ray for src216->rec41 to rays_output/ray_src216_rec41.npy; path length 18
# Saved ray for src216->rec42 to rays_output/ray_src216_rec42.npy; path length 18
# Saved ray for src216->rec43 to rays_output/ray_src216_rec43.npy; path length 18
# Saved ray for src216->rec44 to rays_output/ray_src216_rec44.npy; path length 18
# Saved ray for src216->rec45 to rays_output/ray_src216_rec45.npy; path length 20
# Saved ray for src216->rec46 to rays_output/ray_src216_rec46.npy; path length 19
# Saved ray for src216->rec47 to rays_output/ray_src216_rec47.npy; path length 16
# Saved ray for src216->rec48 to rays_output/ray_src216_rec48.npy; path length 16
# Saved ray for src216->rec49 to rays_output/ray_src216_rec49.npy; path length 17
# Saved ray for src216->rec50 to rays_output/ray_src216_rec50.npy; path length 17
# Saved ray for src216->rec51 to rays_output/ray_src216_rec51.npy; path length 17
# Saved ray for src216->rec52 to rays_output/ray_src216_rec52.npy; path length 17
# Saved ray for src216->rec53 to rays_output/ray_src216_rec53.npy; path length 17
# Saved ray for src216->rec54 to rays_output/ray_src216_rec54.npy; path length 17
# Saved ray for src216->rec55 to rays_output/ray_src216_rec55.npy; path length 17
# Saved ray for src216->rec56 to rays_output/ray_src216_rec56.npy; path length 17
# Saved ray for src216->rec57 to rays_output/ray_src216_rec57.npy; path length 16
# Saved ray for src216->rec58 to rays_output/ray_src216_rec58.npy; path length 16
# Saved ray for src216->rec59 to rays_output/ray_src216_rec59.npy; path length 16
# Saved ray for src216->rec60 to rays_output/ray_src216_rec60.npy; path length 17
# Saved ray for src216->rec61 to rays_output/ray_src216_rec61.npy; path length 16
# Saved ray for src216->rec62 to rays_output/ray_src216_rec62.npy; path length 17
# Saved ray for src216->rec63 to rays_output/ray_src216_rec63.npy; path length 21
# Saved ray for src216->rec64 to rays_output/ray_src216_rec64.npy; path length 21
# Saved ray for src216->rec65 to rays_output/ray_src216_rec65.npy; path length 22
# Saved ray for src216->rec66 to rays_output/ray_src216_rec66.npy; path length 22
# Saved ray for src216->rec67 to rays_output/ray_src216_rec67.npy; path length 23
# Saved ray for src216->rec68 to rays_output/ray_src216_rec68.npy; path length 22
# Saved ray for src216->rec69 to rays_output/ray_src216_rec69.npy; path length 23
# Saved ray for src216->rec70 to rays_output/ray_src216_rec70.npy; path length 22
# Saved ray for src216->rec71 to rays_output/ray_src216_rec71.npy; path length 21
# Saved ray for src216->rec72 to rays_output/ray_src216_rec72.npy; path length 20
# Saved ray for src216->rec73 to rays_output/ray_src216_rec73.npy; path length 21
# Saved ray for src216->rec74 to rays_output/ray_src216_rec74.npy; path length 24
# Saved ray for src216->rec75 to rays_output/ray_src216_rec75.npy; path length 19
# Saved ray for src216->rec76 to rays_output/ray_src216_rec76.npy; path length 20
# Saved ray for src216->rec77 to rays_output/ray_src216_rec77.npy; path length 20
# Saved ray for src216->rec78 to rays_output/ray_src216_rec78.npy; path length 21
# Saved ray for src216->rec79 to rays_output/ray_src216_rec79.npy; path length 21
# Saved ray for src216->rec80 to rays_output/ray_src216_rec80.npy; path length 21
# Saved ray for src216->rec81 to rays_output/ray_src216_rec81.npy; path length 20
# Saved ray for src216->rec82 to rays_output/ray_src216_rec82.npy; path length 19
# Saved ray for src216->rec83 to rays_output/ray_src216_rec83.npy; path length 18
# Saved ray for src216->rec84 to rays_output/ray_src216_rec84.npy; path length 19
# Saved ray for src216->rec85 to rays_output/ray_src216_rec85.npy; path length 19
# Saved ray for src216->rec86 to rays_output/ray_src216_rec86.npy; path length 21
# Saved ray for src216->rec87 to rays_output/ray_src216_rec87.npy; path length 22
# Saved ray for src216->rec88 to rays_output/ray_src216_rec88.npy; path length 21
# Saved ray for src216->rec89 to rays_output/ray_src216_rec89.npy; path length 20
# Saved ray for src216->rec90 to rays_output/ray_src216_rec90.npy; path length 18
# Saved ray for src216->rec91 to rays_output/ray_src216_rec91.npy; path length 18
# Saved ray for src216->rec92 to rays_output/ray_src216_rec92.npy; path length 18
# Saved ray for src216->rec93 to rays_output/ray_src216_rec93.npy; path length 19
# Saved ray for src216->rec94 to rays_output/ray_src216_rec94.npy; path length 19
# Saved ray for src216->rec95 to rays_output/ray_src216_rec95.npy; path length 20
# Saved ray for src216->rec96 to rays_output/ray_src216_rec96.npy; path length 20
# Saved ray for src216->rec97 to rays_output/ray_src216_rec97.npy; path length 19
# Saved ray for src216->rec98 to rays_output/ray_src216_rec98.npy; path length 19
# Saved ray for src216->rec99 to rays_output/ray_src216_rec99.npy; path length 18
# Saved ray for src216->rec100 to rays_output/ray_src216_rec100.npy; path length 18
# Saved ray for src216->rec101 to rays_output/ray_src216_rec101.npy; path length 18
# Saved ray for src216->rec102 to rays_output/ray_src216_rec102.npy; path length 19
# Saved ray for src216->rec103 to rays_output/ray_src216_rec103.npy; path length 19
# Saved ray for src216->rec104 to rays_output/ray_src216_rec104.npy; path length 18
# Saved ray for src216->rec105 to rays_output/ray_src216_rec105.npy; path length 18
# Saved ray for src216->rec106 to rays_output/ray_src216_rec106.npy; path length 18
# Saved ray for src216->rec107 to rays_output/ray_src216_rec107.npy; path length 19
# Saved ray for src216->rec108 to rays_output/ray_src216_rec108.npy; path length 19
# Saved ray for src216->rec109 to rays_output/ray_src216_rec109.npy; path length 20
# Saved ray for src216->rec110 to rays_output/ray_src216_rec110.npy; path length 20
# Saved ray for src216->rec111 to rays_output/ray_src216_rec111.npy; path length 19
# Saved ray for src216->rec112 to rays_output/ray_src216_rec112.npy; path length 19
# Saved ray for src216->rec113 to rays_output/ray_src216_rec113.npy; path length 18
# Saved ray for src216->rec114 to rays_output/ray_src216_rec114.npy; path length 18
# Saved ray for src216->rec115 to rays_output/ray_src216_rec115.npy; path length 18
# Saved ray for src216->rec116 to rays_output/ray_src216_rec116.npy; path length 19
# Saved ray for src216->rec117 to rays_output/ray_src216_rec117.npy; path length 19
# Saved ray for src216->rec118 to rays_output/ray_src216_rec118.npy; path length 18
# Saved ray for src216->rec119 to rays_output/ray_src216_rec119.npy; path length 18
# Saved ray for src216->rec120 to rays_output/ray_src216_rec120.npy; path length 18
# Saved ray for src216->rec121 to rays_output/ray_src216_rec121.npy; path length 19
# Saved ray for src216->rec122 to rays_output/ray_src216_rec122.npy; path length 19
# Saved ray for src216->rec123 to rays_output/ray_src216_rec123.npy; path length 19
# Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.
# Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.
# Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.
# Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.
# Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.
# Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.
# Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.
# Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.
# Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.
# Saved ray for src216->rec133 to rays_output/ray_src216_rec133.npy; path length 21
# Saved ray for src216->rec134 to rays_output/ray_src216_rec134.npy; path length 21
# Saved ray for src216->rec135 to rays_output/ray_src216_rec135.npy; path length 20
# Saved ray for src216->rec136 to rays_output/ray_src216_rec136.npy; path length 17
# Saved ray for src216->rec137 to rays_output/ray_src216_rec137.npy; path length 17
# Saved ray for src216->rec138 to rays_output/ray_src216_rec138.npy; path length 18
# Saved ray for src216->rec139 to rays_output/ray_src216_rec139.npy; path length 18
# Saved ray for src216->rec140 to rays_output/ray_src216_rec140.npy; path length 17
# Saved ray for src216->rec141 to rays_output/ray_src216_rec141.npy; path length 17
# Saved ray for src216->rec142 to rays_output/ray_src216_rec142.npy; path length 17
# Saved ray for src216->rec143 to rays_output/ray_src216_rec143.npy; path length 17
# Saved ray for src216->rec144 to rays_output/ray_src216_rec144.npy; path length 17
# Saved ray for src216->rec145 to rays_output/ray_src216_rec145.npy; path length 17
# Saved ray for src216->rec146 to rays_output/ray_src216_rec146.npy; path length 17
# Saved ray for src216->rec147 to rays_output/ray_src216_rec147.npy; path length 17
# Saved ray for src216->rec148 to rays_output/ray_src216_rec148.npy; path length 17
# Saved ray for src216->rec149 to rays_output/ray_src216_rec149.npy; path length 17
# Saved ray for src216->rec150 to rays_output/ray_src216_rec150.npy; path length 17
# Saved ray for src216->rec151 to rays_output/ray_src216_rec151.npy; path length 17
# Saved ray for src216->rec152 to rays_output/ray_src216_rec152.npy; path length 17
# Saved ray for src216->rec153 to rays_output/ray_src216_rec153.npy; path length 17
# Saved ray for src216->rec154 to rays_output/ray_src216_rec154.npy; path length 17
# Saved ray for src216->rec155 to rays_output/ray_src216_rec155.npy; path length 18
# Saved ray for src216->rec156 to rays_output/ray_src216_rec156.npy; path length 18
# Saved ray for src216->rec157 to rays_output/ray_src216_rec157.npy; path length 19
# Saved ray for src216->rec158 to rays_output/ray_src216_rec158.npy; path length 19
# Saved ray for src216->rec159 to rays_output/ray_src216_rec159.npy; path length 18
# Saved ray for src216->rec160 to rays_output/ray_src216_rec160.npy; path length 18
# Saved ray for src216->rec161 to rays_output/ray_src216_rec161.npy; path length 17
# Saved ray for src216->rec162 to rays_output/ray_src216_rec162.npy; path length 18
# Saved ray for src216->rec163 to rays_output/ray_src216_rec163.npy; path length 17
# Saved ray for src216->rec164 to rays_output/ray_src216_rec164.npy; path length 19
# Saved ray for src216->rec165 to rays_output/ray_src216_rec165.npy; path length 19
# Saved ray for src216->rec166 to rays_output/ray_src216_rec166.npy; path length 20
# Saved ray for src216->rec167 to rays_output/ray_src216_rec167.npy; path length 24
# Saved ray for src216->rec168 to rays_output/ray_src216_rec168.npy; path length 20
# Saved ray for src216->rec169 to rays_output/ray_src216_rec169.npy; path length 20
# Saved ray for src216->rec170 to rays_output/ray_src216_rec170.npy; path length 20
# Saved ray for src216->rec171 to rays_output/ray_src216_rec171.npy; path length 20
# Saved ray for src216->rec172 to rays_output/ray_src216_rec172.npy; path length 20
# Saved ray for src216->rec173 to rays_output/ray_src216_rec173.npy; path length 20
# Saved ray for src216->rec174 to rays_output/ray_src216_rec174.npy; path length 23
# Saved ray for src216->rec175 to rays_output/ray_src216_rec175.npy; path length 23
# Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.
# Saved ray for src216->rec177 to rays_output/ray_src216_rec177.npy; path length 18
# Saved ray for src216->rec178 to rays_output/ray_src216_rec178.npy; path length 21
# Saved ray for src217->rec0 to rays_output/ray_src217_rec0.npy; path length 23
# Saved ray for src217->rec1 to rays_output/ray_src217_rec1.npy; path length 22
# Saved ray for src217->rec2 to rays_output/ray_src217_rec2.npy; path length 23
# Saved ray for src217->rec3 to rays_output/ray_src217_rec3.npy; path length 21
# Saved ray for src217->rec4 to rays_output/ray_src217_rec4.npy; path length 21
# Saved ray for src217->rec5 to rays_output/ray_src217_rec5.npy; path length 20
# Saved ray for src217->rec6 to rays_output/ray_src217_rec6.npy; path length 20
# Saved ray for src217->rec7 to rays_output/ray_src217_rec7.npy; path length 20
# Saved ray for src217->rec8 to rays_output/ray_src217_rec8.npy; path length 19
# Saved ray for src217->rec9 to rays_output/ray_src217_rec9.npy; path length 20
# Saved ray for src217->rec10 to rays_output/ray_src217_rec10.npy; path length 21
# Saved ray for src217->rec11 to rays_output/ray_src217_rec11.npy; path length 21
# Saved ray for src217->rec12 to rays_output/ray_src217_rec12.npy; path length 20
# Saved ray for src217->rec13 to rays_output/ray_src217_rec13.npy; path length 20
# Saved ray for src217->rec14 to rays_output/ray_src217_rec14.npy; path length 20
# Saved ray for src217->rec15 to rays_output/ray_src217_rec15.npy; path length 18
# Saved ray for src217->rec16 to rays_output/ray_src217_rec16.npy; path length 18
# Saved ray for src217->rec17 to rays_output/ray_src217_rec17.npy; path length 18
# Saved ray for src217->rec18 to rays_output/ray_src217_rec18.npy; path length 18
# Saved ray for src217->rec19 to rays_output/ray_src217_rec19.npy; path length 19
# Saved ray for src217->rec20 to rays_output/ray_src217_rec20.npy; path length 19
# Saved ray for src217->rec21 to rays_output/ray_src217_rec21.npy; path length 18
# Saved ray for src217->rec22 to rays_output/ray_src217_rec22.npy; path length 17
# Saved ray for src217->rec23 to rays_output/ray_src217_rec23.npy; path length 17
# Saved ray for src217->rec24 to rays_output/ray_src217_rec24.npy; path length 17
# Saved ray for src217->rec25 to rays_output/ray_src217_rec25.npy; path length 17
# Saved ray for src217->rec26 to rays_output/ray_src217_rec26.npy; path length 18
# Saved ray for src217->rec27 to rays_output/ray_src217_rec27.npy; path length 18
# Saved ray for src217->rec28 to rays_output/ray_src217_rec28.npy; path length 18
# Saved ray for src217->rec29 to rays_output/ray_src217_rec29.npy; path length 18
# Saved ray for src217->rec30 to rays_output/ray_src217_rec30.npy; path length 18
# Saved ray for src217->rec31 to rays_output/ray_src217_rec31.npy; path length 18
# Saved ray for src217->rec32 to rays_output/ray_src217_rec32.npy; path length 18
# Saved ray for src217->rec33 to rays_output/ray_src217_rec33.npy; path length 18
# Saved ray for src217->rec34 to rays_output/ray_src217_rec34.npy; path length 18
# Saved ray for src217->rec35 to rays_output/ray_src217_rec35.npy; path length 17
# Saved ray for src217->rec36 to rays_output/ray_src217_rec36.npy; path length 17
# Saved ray for src217->rec37 to rays_output/ray_src217_rec37.npy; path length 17
# Saved ray for src217->rec38 to rays_output/ray_src217_rec38.npy; path length 17
# Saved ray for src217->rec39 to rays_output/ray_src217_rec39.npy; path length 17
# Saved ray for src217->rec40 to rays_output/ray_src217_rec40.npy; path length 18
# Saved ray for src217->rec41 to rays_output/ray_src217_rec41.npy; path length 18
# Saved ray for src217->rec42 to rays_output/ray_src217_rec42.npy; path length 18
# Saved ray for src217->rec43 to rays_output/ray_src217_rec43.npy; path length 18
# Saved ray for src217->rec44 to rays_output/ray_src217_rec44.npy; path length 18
# Saved ray for src217->rec45 to rays_output/ray_src217_rec45.npy; path length 20
# Saved ray for src217->rec46 to rays_output/ray_src217_rec46.npy; path length 19
# Saved ray for src217->rec47 to rays_output/ray_src217_rec47.npy; path length 16
# Saved ray for src217->rec48 to rays_output/ray_src217_rec48.npy; path length 16
# Saved ray for src217->rec49 to rays_output/ray_src217_rec49.npy; path length 17
# Saved ray for src217->rec50 to rays_output/ray_src217_rec50.npy; path length 17
# Saved ray for src217->rec51 to rays_output/ray_src217_rec51.npy; path length 17
# Saved ray for src217->rec52 to rays_output/ray_src217_rec52.npy; path length 17
# Saved ray for src217->rec53 to rays_output/ray_src217_rec53.npy; path length 17
# Saved ray for src217->rec54 to rays_output/ray_src217_rec54.npy; path length 17
# Saved ray for src217->rec55 to rays_output/ray_src217_rec55.npy; path length 17
# Saved ray for src217->rec56 to rays_output/ray_src217_rec56.npy; path length 17
# Saved ray for src217->rec57 to rays_output/ray_src217_rec57.npy; path length 16
# Saved ray for src217->rec58 to rays_output/ray_src217_rec58.npy; path length 16
# Saved ray for src217->rec59 to rays_output/ray_src217_rec59.npy; path length 16
# Saved ray for src217->rec60 to rays_output/ray_src217_rec60.npy; path length 17
# Saved ray for src217->rec61 to rays_output/ray_src217_rec61.npy; path length 16
# Saved ray for src217->rec62 to rays_output/ray_src217_rec62.npy; path length 17
# Saved ray for src217->rec63 to rays_output/ray_src217_rec63.npy; path length 21
# Saved ray for src217->rec64 to rays_output/ray_src217_rec64.npy; path length 21
# Saved ray for src217->rec65 to rays_output/ray_src217_rec65.npy; path length 22
# Saved ray for src217->rec66 to rays_output/ray_src217_rec66.npy; path length 22
# Saved ray for src217->rec67 to rays_output/ray_src217_rec67.npy; path length 23
# Saved ray for src217->rec68 to rays_output/ray_src217_rec68.npy; path length 22
# Saved ray for src217->rec69 to rays_output/ray_src217_rec69.npy; path length 23
# ...
# ('rec', 226, 127, 'Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.')
# ('rec', 226, 128, 'Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.')
# ('rec', 226, 129, 'Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.')
# ('rec', 226, 130, 'Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.')
# ('rec', 226, 131, 'Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.')
# ('rec', 226, 132, 'Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.')
# ('rec', 226, 176, 'Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.')
# ('rec', 227, 124, 'Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.')
# ('rec', 227, 125, 'Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.')
# ('rec', 227, 126, 'Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.')
# ('rec', 227, 127, 'Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.')
# ('rec', 227, 128, 'Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.')
# ('rec', 227, 129, 'Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.')
# ('rec', 227, 130, 'Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.')
# ('rec', 227, 131, 'Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.')
# ('rec', 227, 132, 'Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.')
# ('rec', 227, 176, 'Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.')
# ('rec', 228, 124, 'Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.')
# ('rec', 228, 125, 'Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.')
# ('rec', 228, 126, 'Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.')
# ('rec', 228, 127, 'Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.')
# ('rec', 228, 128, 'Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.')
# ('rec', 228, 129, 'Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.')
# ('rec', 228, 130, 'Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.')
# ('rec', 228, 131, 'Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.')
# ('rec', 228, 132, 'Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.')
# ('rec', 228, 176, 'Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.')
# ('rec', 229, 124, 'Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.')
# ('rec', 229, 125, 'Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.')
# ('rec', 229, 126, 'Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.')
# ('rec', 229, 127, 'Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.')
# ('rec', 229, 128, 'Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.')
# ('rec', 229, 129, 'Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.')
# ('rec', 229, 130, 'Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.')
# ('rec', 229, 131, 'Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.')
# ('rec', 229, 132, 'Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.')
# ('rec', 229, 176, 'Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.')
# ('rec', 230, 124, 'Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.')
# ('rec', 230, 125, 'Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.')
# ('rec', 230, 126, 'Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.')
# ('rec', 230, 127, 'Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.')
# ('rec', 230, 128, 'Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.')
# ('rec', 230, 129, 'Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.')
# ('rec', 230, 130, 'Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.')
# ('rec', 230, 131, 'Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.')
# ('rec', 230, 132, 'Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.')
# ('rec', 230, 176, 'Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.')
# ('rec', 231, 124, 'Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.')
# ('rec', 231, 125, 'Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.')
# ('rec', 231, 126, 'Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.')
# ('rec', 231, 127, 'Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.')
# ('rec', 231, 128, 'Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.')
# ('rec', 231, 129, 'Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.')
# ('rec', 231, 130, 'Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.')
# ('rec', 231, 131, 'Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.')
# ('rec', 231, 132, 'Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.')
# ('rec', 231, 176, 'Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.')
# ('rec', 232, 124, 'Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.')
# ('rec', 232, 125, 'Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.')
# ('rec', 232, 126, 'Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.')
# ('rec', 232, 127, 'Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.')
# ('rec', 232, 128, 'Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.')
# ('rec', 232, 129, 'Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.')
# ('rec', 232, 130, 'Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.')
# ('rec', 232, 131, 'Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.')
# ('rec', 232, 132, 'Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.')
# ('rec', 232, 176, 'Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.')
# ('rec', 233, 124, 'Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.')
# ('rec', 233, 125, 'Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.')
# ('rec', 233, 126, 'Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.')
# ('rec', 233, 127, 'Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.')
# ('rec', 233, 128, 'Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.')
# ('rec', 233, 129, 'Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.')
# ('rec', 233, 130, 'Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.')
# ('rec', 233, 131, 'Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.')
# ('rec', 233, 132, 'Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.')
# ('rec', 233, 176, 'Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.')
# ('rec', 234, 124, 'Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.')
# ('rec', 234, 125, 'Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.')
# ('rec', 234, 126, 'Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.')
# ('rec', 234, 127, 'Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.')
# ('rec', 234, 128, 'Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.')
# ('rec', 234, 129, 'Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.')
# ('rec', 234, 130, 'Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.')
# ('rec', 234, 131, 'Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.')
# ('rec', 234, 132, 'Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.')
# ('rec', 234, 176, 'Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.')
# ('rec', 235, 124, 'Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.')
# ('rec', 235, 125, 'Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.')
# ('rec', 235, 126, 'Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.')
# ('rec', 235, 127, 'Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.')
# ('rec', 235, 128, 'Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.')
# ('rec', 235, 129, 'Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.')
# ('rec', 235, 130, 'Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.')
# ('rec', 235, 131, 'Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.')
# ('rec', 235, 132, 'Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.')
# ('rec', 235, 176, 'Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.')
# ('rec', 236, 124, 'Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.')
# ('rec', 236, 125, 'Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.')
# ('rec', 236, 126, 'Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.')
# ('rec', 236, 127, 'Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.')
# ('rec', 236, 128, 'Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.')
# ('rec', 236, 129, 'Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.')
# ('rec', 236, 130, 'Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.')
# ('rec', 236, 131, 'Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.')
# ('rec', 236, 132, 'Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.')
# ('rec', 236, 176, 'Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.')
# ('rec', 237, 124, 'Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.')
# ('rec', 237, 125, 'Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.')
# ('rec', 237, 126, 'Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.')
# ('rec', 237, 127, 'Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.')
# ('rec', 237, 128, 'Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.')
# ('rec', 237, 129, 'Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.')
# ('rec', 237, 130, 'Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.')
# ('rec', 237, 131, 'Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.')
# ('rec', 237, 132, 'Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.')
# ('rec', 237, 176, 'Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.')
# ('rec', 238, 124, 'Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.')
# ('rec', 238, 125, 'Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.')
# ('rec', 238, 126, 'Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.')
# ('rec', 238, 127, 'Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.')
# ('rec', 238, 128, 'Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.')
# ('rec', 238, 129, 'Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.')
# ('rec', 238, 130, 'Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.')
# ('rec', 238, 131, 'Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.')
# ('rec', 238, 132, 'Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.')
# ('rec', 238, 176, 'Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.')
# ('rec', 239, 124, 'Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.')
# ('rec', 239, 125, 'Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.')
# ('rec', 239, 126, 'Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.')
# ('rec', 239, 127, 'Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.')
# ('rec', 239, 128, 'Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.')
# ('rec', 239, 129, 'Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.')
# ('rec', 239, 130, 'Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.')
# ('rec', 239, 131, 'Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.')
# ('rec', 239, 132, 'Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.')
# ('rec', 239, 176, 'Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.')
# ('rec', 240, 124, 'Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.')
# ('rec', 240, 125, 'Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.')
# ('rec', 240, 126, 'Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.')
# ('rec', 240, 127, 'Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.')
# ('rec', 240, 128, 'Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.')
# ('rec', 240, 129, 'Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.')
# ('rec', 240, 130, 'Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.')
# ('rec', 240, 131, 'Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.')
# ('rec', 240, 132, 'Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.')
# ('rec', 240, 176, 'Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.')
# ('rec', 241, 124, 'Receiver 124 at [5.92995506 9.03193001 0.2424129 ] is outside domain; skipping.')
# ('rec', 241, 125, 'Receiver 125 at [5.63168912 9.09718896 0.21890717] is outside domain; skipping.')
# ('rec', 241, 126, 'Receiver 126 at [5.30454843 9.15602629 0.19770504] is outside domain; skipping.')
# ('rec', 241, 127, 'Receiver 127 at [5.18577735 9.48402647 0.17560077] is outside domain; skipping.')
# ('rec', 241, 128, 'Receiver 128 at [5.49098366 9.84181276 0.17743493] is outside domain; skipping.')
# ('rec', 241, 129, 'Receiver 129 at [5.43585636 9.36701208 0.2027758 ] is outside domain; skipping.')
# ('rec', 241, 130, 'Receiver 130 at [5.76570911 9.35145584 0.21668374] is outside domain; skipping.')
# ('rec', 241, 131, 'Receiver 131 at [5.59119573 9.90880744 0.17406474] is outside domain; skipping.')
# ('rec', 241, 132, 'Receiver 132 at [5.58907592 9.90505684 0.17225328] is outside domain; skipping.')
# ('rec', 241, 176, 'Receiver 176 at [ 3.48613802 -0.09119256  0.0950693 ] is outside domain; skipping.')

# %%
import os
import numpy as np
import pandas as pd
import csv
import pykonal
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401

# ---- Compatibility patch for NumPy >= 2.0 (pykonal uses np.infty in some versions) ----
if not hasattr(np, "infty"):
    np.infty = np.inf

# -------------------- Parsing utilities --------------------
def parse_dat_file(dat_path):
    """
    Parse the .dat file format you showed.
    Returns: dict mapping source_id -> list of records
    each record: {'station': str, 'tt': float, 'weight': float, 'phase': 'P'/'S'}
    """
    sources = {}
    current_source = None
    with open(dat_path, "r") as f:
        for raw in f:
            line = raw.strip()
            if not line:
                continue
            if line.startswith("#"):
                # header line; take last token as source id (strip '#')
                tokens = line[1:].strip().split()
                if len(tokens) == 0:
                    continue
                current_source = tokens[-1]
                if current_source not in sources:
                    sources[current_source] = []
                continue

            # parse entry lines like: NAME   0.70   1.00  P
            parts = line.split()
            if len(parts) < 4:
                # skip malformed lines
                continue
            station = parts[0]
            try:
                tt = float(parts[1])
            except Exception:
                tt = np.nan
            try:
                weight = float(parts[2])
            except Exception:
                weight = np.nan
            phase = parts[3].upper()
            if current_source is None:
                # if file starts without header, skip
                continue
            sources[current_source].append({"station": station, "tt": tt, "weight": weight, "phase": phase})
    return sources

# -------------------- Station/source coordinate loaders --------------------
def load_station_coords_csv(station_csv):
    """
    station_csv: CSV with header: name,x,y,z  (z optional; if missing, z=0)
    Returns dict: name -> np.array([x,y,z])
    """
    coords = {}
    with open(station_csv, newline="") as csvfile:
        rdr = csv.DictReader(csvfile)
        for row in rdr:
            name = row.get("name") or row.get("station") or row.get("sta") or row.get("s")
            if name is None:
                continue
            x = float(row.get("x_m"))/1000
            y = float(row.get("y_m"))/1000
            z = float(row.get("elev"))/1000
            coords[name] = np.array([x, y, z], dtype=float)
    return coords

def load_source_coords_csv(source_csv):
    """
    Read events / sources CSV and return dict mapping source_id (string) -> np.array([x_km, y_km, z_km]).
    Handles common column names: 'name','id','event','event_id'. Accepts whitespace-delimited files.
    Converts x_m,y_m,elev from meters -> kilometers (divide by 1000).
    """
    import pandas as pd
    coords = {}

    # read with whitespace delimiting (your sample file looks whitespace-separated)
    df = pd.read_csv(source_csv, delim_whitespace=True, dtype=str)
    # strip whitespace from column names
    df.columns = df.columns.str.strip()

    # normalize column names to lower-case for detection
    cols_lower = {c.lower(): c for c in df.columns}

    # try to find id column
    id_col = None
    for candidate in ("name", "id", "event", "event_id", "name_id"):
        if candidate in cols_lower:
            id_col = cols_lower[candidate]
            break
    # fallback: if 'date'+'time' pair could be used as unique id, create one
    if id_col is None:
        # if there's a 'name' like column with numeric labels, pandas may have parsed it differently.
        # fall back to using the row index as ID (string)
        df["__generated_id__"] = df.index.astype(str)
        id_col = "__generated_id__"

    # try to find coordinate columns
    x_col = cols_lower.get("x_m") or cols_lower.get("x") or next((c for c in df.columns if c.lower().startswith("x")), None)
    y_col = cols_lower.get("y_m") or cols_lower.get("y") or next((c for c in df.columns if c.lower().startswith("y")), None)
    z_col = cols_lower.get("elev") or cols_lower.get("z") or cols_lower.get("depth") or next((c for c in df.columns if c.lower().startswith("e")), None)

    if x_col is None or y_col is None:
        raise ValueError(f"Could not detect x/y columns in {source_csv}. Found columns: {list(df.columns)}")

    # coerce numeric columns (safe conversion), fill or raise if not convertible
    df[x_col] = pd.to_numeric(df[x_col], errors="coerce")
    df[y_col] = pd.to_numeric(df[y_col], errors="coerce")
    if z_col is not None:
        df[z_col] = pd.to_numeric(df[z_col], errors="coerce")
    else:
        # if no z/elev, create zeros
        df["__z__"] = 0.0
        z_col = "__z__"

    # convert meters -> kilometers consistently
    df[x_col] = df[x_col] / 1000.0
    df[y_col] = df[y_col] / 1000.0
    df[z_col] = df[z_col]

    # build dict mapping string ids to np.array coords
    for _, row in df.iterrows():
        raw_id = row[id_col]
        if pd.isna(raw_id):
            continue
        src_id = str(raw_id).strip()
        if pd.isna(row[x_col]) or pd.isna(row[y_col]) or pd.isna(row[z_col]):
            # skip or warn if coordinate missing
            print(f"[WARN] skipping source {src_id} because of missing coordinates")
            continue
        coords[src_id] = np.array([row[x_col], row[y_col], row[z_col]], dtype=float)

    # helpful debug print
    print(f"[INFO] Loaded {len(coords)} source coords from {source_csv} (id column: '{id_col}', x/y/z: '{x_col}/{y_col}/{z_col}')")
    # optionally show a few keys
    sample_keys = list(coords.keys())[:8]
    print(f"[INFO] example source IDs: {sample_keys}")
    return coords

# -------------------- PyKonal grid builder --------------------
def build_solver_grid(min_coords=(0.0,0.0,0.0), node_intervals=(1.0,1.0,1.0), npts=(10,10,10),
                      top_layer_vel=5.5, other_vel=5.76, coord_sys="cartesian"):
    solver = pykonal.EikonalSolver(coord_sys=coord_sys)
    solver.velocity.min_coords = tuple(min_coords)
    solver.velocity.node_intervals = tuple(node_intervals)
    solver.velocity.npts = tuple(npts)
    nx, ny, nz = solver.velocity.npts
    vel = np.empty((nx, ny, nz), dtype=float)
    vel[:,:,:] = other_vel
    vel[:, :, 0] = top_layer_vel
    solver.velocity.values = vel
    return solver

def point_inside_domain(pt, solver):
    minc = np.array(solver.velocity.min_coords, dtype=float)
    intervals = np.array(solver.velocity.node_intervals, dtype=float)
    npts = np.array(solver.velocity.npts, dtype=int)
    maxc = minc + (npts - 1) * intervals
    return np.all(pt >= minc - 1e-8) and np.all(pt <= maxc + 1e-8)

# -------------------- Ray-tracing core --------------------
def trace_phase_rays(sources_dict, station_coords, source_coords,
                     phase="P", out_dir="rays_output",
                     grid_params=None):
    """
    sources_dict: output of parse_dat_file
    station_coords: dict station->coord
    source_coords: dict source_id->coord
    phase: 'P' or 'S'
    grid_params: dict with keys min_coords,node_intervals,npts,top_layer_vel,other_vel
    """
    os.makedirs(out_dir, exist_ok=True)

    # Defaults if not provided
    if grid_params is None:
        grid_params = {
            "min_coords": (-5,-4,0.0),
            "node_intervals": (1.0,1.0,1.0),
            "npts": (10,10,10),
            "top_layer_vel": 5.5,
            "other_vel": 5.76,
            "coord_sys": "cartesian",
        }

    # prototype solver for domain checks
    proto = build_solver_grid(min_coords=grid_params["min_coords"],
                              node_intervals=grid_params["node_intervals"],
                              npts=grid_params["npts"],
                              top_layer_vel=grid_params["top_layer_vel"],
                              other_vel=grid_params["other_vel"],
                              coord_sys=grid_params.get("coord_sys","cartesian"))
    min_coords = np.array(proto.velocity.min_coords)
    intervals = np.array(proto.velocity.node_intervals)
    npts = proto.velocity.npts

    rays_saved = []
    failures = []

    for src_id, picks in sources_dict.items():
        # filter picks by phase
        picks_phase = [p for p in picks if p["phase"] == phase]
        if len(picks_phase) == 0:
            continue

        # look up source coordinate
        if src_id not in source_coords:
            failures.append(("no_source_coord", src_id, f"Source {src_id} not in source_coords"))
            print(f"[WARN] source {src_id} has no coordinate mapping; skipping")
            continue
        src_coord = np.asarray(source_coords[src_id], dtype=float)
        if not point_inside_domain(src_coord, proto):
            failures.append(("source_outside", src_id, f"Source {src_id} outside domain"))
            print(f"[WARN] source {src_id} at {src_coord} outside solver domain; skipping")
            continue

        # build fresh solver for this source
        solver = build_solver_grid(min_coords=grid_params["min_coords"],
                              node_intervals=grid_params["node_intervals"],
                              npts=grid_params["npts"],
                              top_layer_vel=grid_params["top_layer_vel"],
                              other_vel=grid_params["other_vel"],
                              coord_sys=grid_params.get("coord_sys","cartesian"))

        # locate nearest grid node index for source
        rel = (src_coord - min_coords) / intervals
        src_idx = tuple(np.round(rel).astype(int).tolist())
        src_idx = (max(0, min(npts[0]-1, src_idx[0])),
                   max(0, min(npts[1]-1, src_idx[1])),
                   max(0, min(npts[2]-1, src_idx[2])))
        try:
            solver.traveltime.values[src_idx] = 0.0
        except Exception as e:
            failures.append(("set_tt_fail", src_id, str(e)))
            print(f"[ERROR] Failed to set traveltime at {src_idx} for source {src_id}: {e}")
            continue

        # try to push the source to trial (some PyKonal builds require it)
        try:
            solver.unknown[src_idx] = False
            solver.trial.push(*src_idx)
        except Exception:
            try:
                solver.traveltime.known[src_idx] = True
                solver.traveltime.unknown[src_idx] = False
                try:
                    solver.traveltime.trial.push(*src_idx)
                except Exception:
                    pass
            except Exception:
                # ignore and proceed; many versions are fine
                pass

        # solve eikonal
        try:
            solver.solve()
        except Exception as e:
            failures.append(("solve_fail", src_id, str(e)))
            print(f"[ERROR] solver.solve failed for source {src_id}: {e}")
            continue

        # now trace rays from receivers for this phase
        for pick in picks_phase:
            sta = pick["station"]
            if sta not in station_coords:
                failures.append(("no_sta_coord", src_id, sta))
                print(f"[WARN] station {sta} missing coords; skipping pick for source {src_id}")
                continue
            rec_coord = np.asarray(station_coords[sta], dtype=float)
            if not point_inside_domain(rec_coord, proto):
                failures.append(("rec_outside", src_id, sta))
                print(f"[WARN] receiver {sta} for source {src_id} outside domain; skipping")
                continue

            # trace: backtrace from receiver physical coordinate to the source
            try:
                ray = solver.trace_ray(rec_coord)
                if ray is None or len(ray) == 0:
                    raise RuntimeError("trace_ray returned empty")
            except Exception as e:
                failures.append(("trace_fail", src_id, sta, str(e)))
                print(f"[ERROR] trace_ray failed for src {src_id} -> rec {sta}: {e}")
                continue

            # save and record
            fname = os.path.join(out_dir, f"ray_src{src_id}_rec{sta}_{phase}.npy")
            np.save(fname, ray)
            rays_saved.append({"src": src_id, "rec": sta, "phase": phase, "file": fname, "ray": ray})
            print(f"Saved ray src={src_id} rec={sta} phase={phase} -> {fname} (path length {len(ray)})")

    return rays_saved, failures

# -------------------- Plotting helper --------------------
def plot_rays_collection(rays_saved, show=True, title=None):
    fig = plt.figure(figsize=(10,8))
    ax = fig.add_subplot(111, projection="3d")
    for rec in rays_saved:
        ray = rec["ray"]
        ax.plot(ray[:,0], ray[:,1], ray[:,2], linewidth=1.2)
        ax.scatter([ray[0,0]], [ray[0,1]], [ray[0,2]], marker="o", s=30)   # receiver (start)
        ax.scatter([ray[-1,0]], [ray[-1,1]], [ray[-1,2]], marker="^", s=40) # source (end)
    ax.set_xlabel("X"); ax.set_ylabel("Y"); ax.set_zlabel("Z")
    if title:
        ax.set_title(title)
    if show:
        plt.show()
    return fig, ax

# -------------------- Example main --------------------
if __name__ == "__main__":
    # paths - change to your files
    dat_file = "absolute.dat"
    station_csv = "stations_cartesian.csv"       # CSV with columns: name,x,y,z
    source_csv = "events_cartesian.csv"         # CSV mapping source-id -> x,y,z

    # parse file
    sources_dict = parse_dat_file(dat_file)
    print(f"Parsed {len(sources_dict)} sources from {dat_file}")

    # load coords
    station_coords = load_station_coords_csv(station_csv)
    source_coords = load_source_coords_csv(source_csv)
    print(f"Loaded {len(station_coords)} station coords and {len(source_coords)} source coords")

    # trace P and S separately
    p_rays, p_fail = trace_phase_rays(sources_dict, station_coords, source_coords, phase="P", out_dir="rays_P")
    s_rays, s_fail = trace_phase_rays(sources_dict, station_coords, source_coords, phase="S", out_dir="rays_S")

    print("P rays saved:", len(p_rays), "P failures:", len(p_fail))
    print("S rays saved:", len(s_rays), "S failures:", len(s_fail))

    # quick plot (example)
    plot_rays_collection(p_rays, title="P-phase rays")
    plot_rays_collection(s_rays, title="S-phase rays")
# Out:
# Parsed 234 sources from absolute.dat
# [INFO] Loaded 233 source coords from events_cartesian.csv (id column: 'name', x/y/z: 'x_m/y_m/elev')
# [INFO] example source IDs: ['1', '2', '3', '4', '5', '6', '7', '8']
# Loaded 179 station coords and 233 source coords
# Saved ray src=1 rec=O102 phase=P -> rays_P/ray_src1_recO102_P.npy (path length 17)
# Saved ray src=1 rec=C101T phase=P -> rays_P/ray_src1_recC101T_P.npy (path length 16)
# Saved ray src=1 rec=C104T phase=P -> rays_P/ray_src1_recC104T_P.npy (path length 16)
# Saved ray src=1 rec=O103 phase=P -> rays_P/ray_src1_recO103_P.npy (path length 17)
# Saved ray src=1 rec=C123 phase=P -> rays_P/ray_src1_recC123_P.npy (path length 30)
# Saved ray src=1 rec=C120 phase=P -> rays_P/ray_src1_recC120_P.npy (path length 17)
# Saved ray src=1 rec=B128 phase=P -> rays_P/ray_src1_recB128_P.npy (path length 17)
# Saved ray src=1 rec=B111 phase=P -> rays_P/ray_src1_recB111_P.npy (path length 17)
# Saved ray src=1 rec=C118 phase=P -> rays_P/ray_src1_recC118_P.npy (path length 17)
# Saved ray src=1 rec=C107 phase=P -> rays_P/ray_src1_recC107_P.npy (path length 17)
# Saved ray src=1 rec=C117 phase=P -> rays_P/ray_src1_recC117_P.npy (path length 17)
# Saved ray src=1 rec=O101S phase=P -> rays_P/ray_src1_recO101S_P.npy (path length 17)
# Saved ray src=1 rec=C109S phase=P -> rays_P/ray_src1_recC109S_P.npy (path length 17)
# Saved ray src=1 rec=N105 phase=P -> rays_P/ray_src1_recN105_P.npy (path length 17)
# Saved ray src=1 rec=N101 phase=P -> rays_P/ray_src1_recN101_P.npy (path length 17)
# Saved ray src=1 rec=B110 phase=P -> rays_P/ray_src1_recB110_P.npy (path length 17)
# Saved ray src=1 rec=B127S phase=P -> rays_P/ray_src1_recB127S_P.npy (path length 17)
# Saved ray src=1 rec=B130 phase=P -> rays_P/ray_src1_recB130_P.npy (path length 17)
# Saved ray src=1 rec=B112 phase=P -> rays_P/ray_src1_recB112_P.npy (path length 17)
# Saved ray src=1 rec=O104 phase=P -> rays_P/ray_src1_recO104_P.npy (path length 17)
# Saved ray src=1 rec=C108S phase=P -> rays_P/ray_src1_recC108S_P.npy (path length 17)
# Saved ray src=1 rec=C122 phase=P -> rays_P/ray_src1_recC122_P.npy (path length 17)
# Saved ray src=1 rec=R137T phase=P -> rays_P/ray_src1_recR137T_P.npy (path length 17)
# Saved ray src=1 rec=N102 phase=P -> rays_P/ray_src1_recN102_P.npy (path length 17)
# Saved ray src=1 rec=C116 phase=P -> rays_P/ray_src1_recC116_P.npy (path length 17)
# Saved ray src=1 rec=B109 phase=P -> rays_P/ray_src1_recB109_P.npy (path length 17)
# Saved ray src=1 rec=O108 phase=P -> rays_P/ray_src1_recO108_P.npy (path length 17)
# Saved ray src=1 rec=B113 phase=P -> rays_P/ray_src1_recB113_P.npy (path length 17)
# Saved ray src=1 rec=A118T phase=P -> rays_P/ray_src1_recA118T_P.npy (path length 17)
# Saved ray src=1 rec=B129 phase=P -> rays_P/ray_src1_recB129_P.npy (path length 17)
# Saved ray src=1 rec=C110 phase=P -> rays_P/ray_src1_recC110_P.npy (path length 17)
# Saved ray src=1 rec=B102 phase=P -> rays_P/ray_src1_recB102_P.npy (path length 17)
# Saved ray src=1 rec=O105 phase=P -> rays_P/ray_src1_recO105_P.npy (path length 17)
# Saved ray src=1 rec=O106 phase=P -> rays_P/ray_src1_recO106_P.npy (path length 17)
# Saved ray src=1 rec=C111 phase=P -> rays_P/ray_src1_recC111_P.npy (path length 17)
# Saved ray src=1 rec=B121 phase=P -> rays_P/ray_src1_recB121_P.npy (path length 17)
# Saved ray src=1 rec=C124 phase=P -> rays_P/ray_src1_recC124_P.npy (path length 17)
# Saved ray src=1 rec=G102 phase=P -> rays_P/ray_src1_recG102_P.npy (path length 17)
# Saved ray src=1 rec=B101 phase=P -> rays_P/ray_src1_recB101_P.npy (path length 17)
# Saved ray src=1 rec=B120S phase=P -> rays_P/ray_src1_recB120S_P.npy (path length 17)
# Saved ray src=1 rec=O109 phase=P -> rays_P/ray_src1_recO109_P.npy (path length 17)
# Saved ray src=1 rec=C115 phase=P -> rays_P/ray_src1_recC115_P.npy (path length 17)
# Saved ray src=1 rec=B124 phase=P -> rays_P/ray_src1_recB124_P.npy (path length 17)
# Saved ray src=1 rec=B108 phase=P -> rays_P/ray_src1_recB108_P.npy (path length 17)
# Saved ray src=1 rec=B123 phase=P -> rays_P/ray_src1_recB123_P.npy (path length 17)
# Saved ray src=1 rec=O123S phase=P -> rays_P/ray_src1_recO123S_P.npy (path length 17)
# Saved ray src=1 rec=B122 phase=P -> rays_P/ray_src1_recB122_P.npy (path length 17)
# Saved ray src=1 rec=H101 phase=P -> rays_P/ray_src1_recH101_P.npy (path length 17)
# Saved ray src=1 rec=G101 phase=P -> rays_P/ray_src1_recG101_P.npy (path length 17)
# Saved ray src=1 rec=B114 phase=P -> rays_P/ray_src1_recB114_P.npy (path length 17)
# Saved ray src=1 rec=C112T phase=P -> rays_P/ray_src1_recC112T_P.npy (path length 17)
# Saved ray src=1 rec=A115T phase=P -> rays_P/ray_src1_recA115T_P.npy (path length 18)
# Saved ray src=1 rec=A115 phase=P -> rays_P/ray_src1_recA115_P.npy (path length 18)
# Saved ray src=1 rec=E125U phase=P -> rays_P/ray_src1_recE125U_P.npy (path length 17)
# Saved ray src=1 rec=B103 phase=P -> rays_P/ray_src1_recB103_P.npy (path length 17)
# Saved ray src=1 rec=H121T phase=P -> rays_P/ray_src1_recH121T_P.npy (path length 17)
# Saved ray src=1 rec=G121T phase=P -> rays_P/ray_src1_recG121T_P.npy (path length 17)
# Saved ray src=1 rec=E101U phase=P -> rays_P/ray_src1_recE101U_P.npy (path length 18)
# Saved ray src=1 rec=O113S phase=P -> rays_P/ray_src1_recO113S_P.npy (path length 17)
# Saved ray src=1 rec=H103T phase=P -> rays_P/ray_src1_recH103T_P.npy (path length 17)
# Saved ray src=1 rec=G103T phase=P -> rays_P/ray_src1_recG103T_P.npy (path length 17)
# Saved ray src=1 rec=A131T phase=P -> rays_P/ray_src1_recA131T_P.npy (path length 18)
# Saved ray src=1 rec=O112S phase=P -> rays_P/ray_src1_recO112S_P.npy (path length 17)
# Saved ray src=1 rec=O110S phase=P -> rays_P/ray_src1_recO110S_P.npy (path length 17)
# Saved ray src=1 rec=H124 phase=P -> rays_P/ray_src1_recH124_P.npy (path length 17)
# Saved ray src=1 rec=G124 phase=P -> rays_P/ray_src1_recG124_P.npy (path length 17)
# Saved ray src=1 rec=K101T phase=P -> rays_P/ray_src1_recK101T_P.npy (path length 17)
# Saved ray src=1 rec=A121T phase=P -> rays_P/ray_src1_recA121T_P.npy (path length 18)
# Saved ray src=1 rec=A134 phase=P -> rays_P/ray_src1_recA134_P.npy (path length 18)
# Saved ray src=1 rec=O121S phase=P -> rays_P/ray_src1_recO121S_P.npy (path length 17)
# Saved ray src=1 rec=H129T phase=P -> rays_P/ray_src1_recH129T_P.npy (path length 17)
# Saved ray src=1 rec=G129T phase=P -> rays_P/ray_src1_recG129T_P.npy (path length 17)
# Saved ray src=1 rec=E104U phase=P -> rays_P/ray_src1_recE104U_P.npy (path length 18)
# Saved ray src=1 rec=A128T phase=P -> rays_P/ray_src1_recA128T_P.npy (path length 18)
# Saved ray src=1 rec=O114 phase=P -> rays_P/ray_src1_recO114_P.npy (path length 17)
# Saved ray src=1 rec=K104 phase=P -> rays_P/ray_src1_recK104_P.npy (path length 17)
# Saved ray src=1 rec=O122 phase=P -> rays_P/ray_src1_recO122_P.npy (path length 17)
# Saved ray src=1 rec=B132 phase=P -> rays_P/ray_src1_recB132_P.npy (path length 17)
# Saved ray src=1 rec=B104S phase=P -> rays_P/ray_src1_recB104S_P.npy (path length 17)
# Saved ray src=1 rec=A112T phase=P -> rays_P/ray_src1_recA112T_P.npy (path length 18)
# Saved ray src=1 rec=E122U phase=P -> rays_P/ray_src1_recE122U_P.npy (path length 18)
# Saved ray src=1 rec=E131U phase=P -> rays_P/ray_src1_recE131U_P.npy (path length 18)
# Saved ray src=1 rec=E128U phase=P -> rays_P/ray_src1_recE128U_P.npy (path length 18)
# Saved ray src=1 rec=H106T phase=P -> rays_P/ray_src1_recH106T_P.npy (path length 17)
# Saved ray src=1 rec=G106T phase=P -> rays_P/ray_src1_recG106T_P.npy (path length 17)
# Saved ray src=1 rec=R101T phase=P -> rays_P/ray_src1_recR101T_P.npy (path length 18)
# Saved ray src=1 rec=A124T phase=P -> rays_P/ray_src1_recA124T_P.npy (path length 18)
# Saved ray src=1 rec=K107T phase=P -> rays_P/ray_src1_recK107T_P.npy (path length 18)
# Saved ray src=1 rec=O120 phase=P -> rays_P/ray_src1_recO120_P.npy (path length 17)
# Saved ray src=1 rec=O115 phase=P -> rays_P/ray_src1_recO115_P.npy (path length 17)
# Saved ray src=1 rec=G125 phase=P -> rays_P/ray_src1_recG125_P.npy (path length 18)
# Saved ray src=1 rec=B117 phase=P -> rays_P/ray_src1_recB117_P.npy (path length 18)
# Saved ray src=1 rec=B107 phase=P -> rays_P/ray_src1_recB107_P.npy (path length 18)
# Saved ray src=1 rec=A106T phase=P -> rays_P/ray_src1_recA106T_P.npy (path length 18)
# /tmp/ipython-input-1132271624.py:87: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(source_csv, delim_whitespace=True, dtype=str)
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Saved ray src=150 rec=B138T phase=S -> rays_S/ray_src150_recB138T_S.npy (path length 18)
# Saved ray src=150 rec=R122T phase=S -> rays_S/ray_src150_recR122T_S.npy (path length 18)
# Saved ray src=150 rec=E107U phase=S -> rays_S/ray_src150_recE107U_S.npy (path length 18)
# Saved ray src=150 rec=E119U phase=S -> rays_S/ray_src150_recE119U_S.npy (path length 18)
# Saved ray src=150 rec=F110T phase=S -> rays_S/ray_src150_recF110T_S.npy (path length 19)
# Saved ray src=150 rec=F107T phase=S -> rays_S/ray_src150_recF107T_S.npy (path length 19)
# Saved ray src=150 rec=B135T phase=S -> rays_S/ray_src150_recB135T_S.npy (path length 18)
# Saved ray src=150 rec=E110U phase=S -> rays_S/ray_src150_recE110U_S.npy (path length 19)
# Saved ray src=150 rec=F101T phase=S -> rays_S/ray_src150_recF101T_S.npy (path length 19)
# Saved ray src=150 rec=M107T phase=S -> rays_S/ray_src150_recM107T_S.npy (path length 19)
# Saved ray src=150 rec=E113U phase=S -> rays_S/ray_src150_recE113U_S.npy (path length 19)
# Saved ray src=150 rec=D125U phase=S -> rays_S/ray_src150_recD125U_S.npy (path length 19)
# Saved ray src=150 rec=F104T phase=S -> rays_S/ray_src150_recF104T_S.npy (path length 19)
# Saved ray src=150 rec=D101U phase=S -> rays_S/ray_src150_recD101U_S.npy (path length 19)
# Saved ray src=150 rec=D104T phase=S -> rays_S/ray_src150_recD104T_S.npy (path length 19)
# Saved ray src=150 rec=A101T phase=S -> rays_S/ray_src150_recA101T_S.npy (path length 19)
# Saved ray src=150 rec=M101T phase=S -> rays_S/ray_src150_recM101T_S.npy (path length 19)
# Saved ray src=150 rec=R140T phase=S -> rays_S/ray_src150_recR140T_S.npy (path length 19)
# Saved ray src=150 rec=R128T phase=S -> rays_S/ray_src150_recR128T_S.npy (path length 20)
# Saved ray src=150 rec=D118U phase=S -> rays_S/ray_src150_recD118U_S.npy (path length 20)
# Saved ray src=150 rec=M104T phase=S -> rays_S/ray_src150_recM104T_S.npy (path length 19)
# Saved ray src=150 rec=D115U phase=S -> rays_S/ray_src150_recD115U_S.npy (path length 20)
# Saved ray src=150 rec=L101U phase=S -> rays_S/ray_src150_recL101U_S.npy (path length 20)
# Saved ray src=150 rec=L113U phase=S -> rays_S/ray_src150_recL113U_S.npy (path length 21)
# Saved ray src=150 rec=L110U phase=S -> rays_S/ray_src150_recL110U_S.npy (path length 21)
# Saved ray src=151 rec=R137T phase=S -> rays_S/ray_src151_recR137T_S.npy (path length 17)
# Saved ray src=151 rec=A118T phase=S -> rays_S/ray_src151_recA118T_S.npy (path length 17)
# Saved ray src=151 rec=K101T phase=S -> rays_S/ray_src151_recK101T_S.npy (path length 17)
# Saved ray src=151 rec=A131T phase=S -> rays_S/ray_src151_recA131T_S.npy (path length 18)
# Saved ray src=151 rec=C112T phase=S -> rays_S/ray_src151_recC112T_S.npy (path length 17)
# Saved ray src=151 rec=K107T phase=S -> rays_S/ray_src151_recK107T_S.npy (path length 18)
# Saved ray src=151 rec=A121T phase=S -> rays_S/ray_src151_recA121T_S.npy (path length 18)
# Saved ray src=151 rec=A112T phase=S -> rays_S/ray_src151_recA112T_S.npy (path length 18)
# Saved ray src=151 rec=R110T phase=S -> rays_S/ray_src151_recR110T_S.npy (path length 18)
# Saved ray src=151 rec=E104U phase=S -> rays_S/ray_src151_recE104U_S.npy (path length 18)
# Saved ray src=151 rec=R107T phase=S -> rays_S/ray_src151_recR107T_S.npy (path length 18)
# Saved ray src=151 rec=R113T phase=S -> rays_S/ray_src151_recR113T_S.npy (path length 18)
# Saved ray src=151 rec=R116T phase=S -> rays_S/ray_src151_recR116T_S.npy (path length 18)
# Saved ray src=151 rec=A106T phase=S -> rays_S/ray_src151_recA106T_S.npy (path length 18)
# Saved ray src=151 rec=E122U phase=S -> rays_S/ray_src151_recE122U_S.npy (path length 18)
# Saved ray src=151 rec=E131U phase=S -> rays_S/ray_src151_recE131U_S.npy (path length 18)
# Saved ray src=151 rec=E128U phase=S -> rays_S/ray_src151_recE128U_S.npy (path length 18)
# Saved ray src=151 rec=R119T phase=S -> rays_S/ray_src151_recR119T_S.npy (path length 18)
# Saved ray src=151 rec=E107U phase=S -> rays_S/ray_src151_recE107U_S.npy (path length 18)
# Saved ray src=151 rec=R122T phase=S -> rays_S/ray_src151_recR122T_S.npy (path length 18)
# Saved ray src=151 rec=B138T phase=S -> rays_S/ray_src151_recB138T_S.npy (path length 18)
# Saved ray src=151 rec=F110T phase=S -> rays_S/ray_src151_recF110T_S.npy (path length 19)
# Saved ray src=151 rec=B135T phase=S -> rays_S/ray_src151_recB135T_S.npy (path length 18)
# Saved ray src=151 rec=M107T phase=S -> rays_S/ray_src151_recM107T_S.npy (path length 19)
# Saved ray src=151 rec=D101U phase=S -> rays_S/ray_src151_recD101U_S.npy (path length 19)
# Saved ray src=151 rec=R140T phase=S -> rays_S/ray_src151_recR140T_S.npy (path length 19)
# Saved ray src=151 rec=M104T phase=S -> rays_S/ray_src151_recM104T_S.npy (path length 19)
# Saved ray src=151 rec=L101U phase=S -> rays_S/ray_src151_recL101U_S.npy (path length 20)
# Saved ray src=151 rec=L113U phase=S -> rays_S/ray_src151_recL113U_S.npy (path length 21)
# Saved ray src=151 rec=L110U phase=S -> rays_S/ray_src151_recL110U_S.npy (path length 21)
# Saved ray src=152 rec=R137T phase=S -> rays_S/ray_src152_recR137T_S.npy (path length 17)
# Saved ray src=152 rec=C101T phase=S -> rays_S/ray_src152_recC101T_S.npy (path length 16)
# Saved ray src=152 rec=C104T phase=S -> rays_S/ray_src152_recC104T_S.npy (path length 16)
# Saved ray src=152 rec=H121T phase=S -> rays_S/ray_src152_recH121T_S.npy (path length 17)
# Saved ray src=152 rec=G121T phase=S -> rays_S/ray_src152_recG121T_S.npy (path length 17)
# Saved ray src=152 rec=A118T phase=S -> rays_S/ray_src152_recA118T_S.npy (path length 17)
# Saved ray src=152 rec=C112T phase=S -> rays_S/ray_src152_recC112T_S.npy (path length 17)
# Saved ray src=152 rec=K107T phase=S -> rays_S/ray_src152_recK107T_S.npy (path length 18)
# Saved ray src=152 rec=E125U phase=S -> rays_S/ray_src152_recE125U_S.npy (path length 17)
# Saved ray src=152 rec=H126T phase=S -> rays_S/ray_src152_recH126T_S.npy (path length 18)
# Saved ray src=152 rec=G126T phase=S -> rays_S/ray_src152_recG126T_S.npy (path length 18)
# Saved ray src=152 rec=A112T phase=S -> rays_S/ray_src152_recA112T_S.npy (path length 18)
# Saved ray src=152 rec=E101U phase=S -> rays_S/ray_src152_recE101U_S.npy (path length 18)
# Saved ray src=152 rec=R110T phase=S -> rays_S/ray_src152_recR110T_S.npy (path length 18)
# Saved ray src=152 rec=R116T phase=S -> rays_S/ray_src152_recR116T_S.npy (path length 18)
# Saved ray src=152 rec=R119T phase=S -> rays_S/ray_src152_recR119T_S.npy (path length 18)
# Saved ray src=152 rec=E122U phase=S -> rays_S/ray_src152_recE122U_S.npy (path length 18)
# Saved ray src=152 rec=E131U phase=S -> rays_S/ray_src152_recE131U_S.npy (path length 18)
# Saved ray src=152 rec=E128U phase=S -> rays_S/ray_src152_recE128U_S.npy (path length 18)
# Saved ray src=152 rec=A106T phase=S -> rays_S/ray_src152_recA106T_S.npy (path length 18)
# Saved ray src=152 rec=R122T phase=S -> rays_S/ray_src152_recR122T_S.npy (path length 18)
# Saved ray src=152 rec=E107U phase=S -> rays_S/ray_src152_recE107U_S.npy (path length 18)
# Saved ray src=152 rec=B138T phase=S -> rays_S/ray_src152_recB138T_S.npy (path length 18)
# Saved ray src=152 rec=F107T phase=S -> rays_S/ray_src152_recF107T_S.npy (path length 19)
# Saved ray src=152 rec=E119U phase=S -> rays_S/ray_src152_recE119U_S.npy (path length 18)
# Saved ray src=152 rec=F101T phase=S -> rays_S/ray_src152_recF101T_S.npy (path length 19)
# Saved ray src=152 rec=B135T phase=S -> rays_S/ray_src152_recB135T_S.npy (path length 18)
# Saved ray src=152 rec=F104T phase=S -> rays_S/ray_src152_recF104T_S.npy (path length 19)
# Saved ray src=152 rec=E113U phase=S -> rays_S/ray_src152_recE113U_S.npy (path length 19)
# Saved ray src=152 rec=D101U phase=S -> rays_S/ray_src152_recD101U_S.npy (path length 19)
# Saved ray src=152 rec=M107T phase=S -> rays_S/ray_src152_recM107T_S.npy (path length 19)
# Saved ray src=152 rec=R131T phase=S -> rays_S/ray_src152_recR131T_S.npy (path length 19)
# Saved ray src=152 rec=R128T phase=S -> rays_S/ray_src152_recR128T_S.npy (path length 20)
# Saved ray src=152 rec=M101T phase=S -> rays_S/ray_src152_recM101T_S.npy (path length 19)
# Saved ray src=152 rec=R140T phase=S -> rays_S/ray_src152_recR140T_S.npy (path length 19)
# Saved ray src=152 rec=D118U phase=S -> rays_S/ray_src152_recD118U_S.npy (path length 20)
# Saved ray src=152 rec=M104T phase=S -> rays_S/ray_src152_recM104T_S.npy (path length 19)
# Saved ray src=152 rec=L101U phase=S -> rays_S/ray_src152_recL101U_S.npy (path length 20)
# Saved ray src=153 rec=C101T phase=S -> rays_S/ray_src153_recC101T_S.npy (path length 17)
# Saved ray src=153 rec=C104T phase=S -> rays_S/ray_src153_recC104T_S.npy (path length 17)
# Saved ray src=153 rec=E101U phase=S -> rays_S/ray_src153_recE101U_S.npy (path length 17)
# Saved ray src=153 rec=A118T phase=S -> rays_S/ray_src153_recA118T_S.npy (path length 17)
# Saved ray src=153 rec=E104U phase=S -> rays_S/ray_src153_recE104U_S.npy (path length 17)
# Saved ray src=153 rec=E122U phase=S -> rays_S/ray_src153_recE122U_S.npy (path length 17)
# Saved ray src=153 rec=E131U phase=S -> rays_S/ray_src153_recE131U_S.npy (path length 17)
# Saved ray src=153 rec=E128U phase=S -> rays_S/ray_src153_recE128U_S.npy (path length 17)
# Saved ray src=153 rec=A121T phase=S -> rays_S/ray_src153_recA121T_S.npy (path length 17)
# Saved ray src=153 rec=R101T phase=S -> rays_S/ray_src153_recR101T_S.npy (path length 17)
# Saved ray src=153 rec=E107U phase=S -> rays_S/ray_src153_recE107U_S.npy (path length 17)
# Saved ray src=153 rec=R137T phase=S -> rays_S/ray_src153_recR137T_S.npy (path length 18)
# Saved ray src=153 rec=C112T phase=S -> rays_S/ray_src153_recC112T_S.npy (path length 18)
# Saved ray src=153 rec=A112T phase=S -> rays_S/ray_src153_recA112T_S.npy (path length 17)
# Saved ray src=153 rec=A106T phase=S -> rays_S/ray_src153_recA106T_S.npy (path length 17)
# Saved ray src=153 rec=B138T phase=S -> rays_S/ray_src153_recB138T_S.npy (path length 18)
# Saved ray src=153 rec=H121T phase=S -> rays_S/ray_src153_recH121T_S.npy (path length 19)
# Saved ray src=153 rec=G121T phase=S -> rays_S/ray_src153_recG121T_S.npy (path length 19)
# Saved ray src=153 rec=B135T phase=S -> rays_S/ray_src153_recB135T_S.npy (path length 18)
# Saved ray src=153 rec=A101T phase=S -> rays_S/ray_src153_recA101T_S.npy (path length 18)
# Saved ray src=153 rec=M107T phase=S -> rays_S/ray_src153_recM107T_S.npy (path length 18)
# Saved ray src=153 rec=H118T phase=S -> rays_S/ray_src153_recH118T_S.npy (path length 19)
# Saved ray src=153 rec=G118T phase=S -> rays_S/ray_src153_recG118T_S.npy (path length 19)
# Saved ray src=153 rec=K107T phase=S -> rays_S/ray_src153_recK107T_S.npy (path length 19)
# Saved ray src=153 rec=R140T phase=S -> rays_S/ray_src153_recR140T_S.npy (path length 19)
# Saved ray src=153 rec=M101T phase=S -> rays_S/ray_src153_recM101T_S.npy (path length 19)
# Saved ray src=153 rec=M104T phase=S -> rays_S/ray_src153_recM104T_S.npy (path length 19)
# Saved ray src=153 rec=L113U phase=S -> rays_S/ray_src153_recL113U_S.npy (path length 19)
# Saved ray src=153 rec=L110U phase=S -> rays_S/ray_src153_recL110U_S.npy (path length 19)
# Saved ray src=153 rec=D118U phase=S -> rays_S/ray_src153_recD118U_S.npy (path length 22)
# Saved ray src=153 rec=D115U phase=S -> rays_S/ray_src153_recD115U_S.npy (path length 23)
# Saved ray src=153 rec=D109U phase=S -> rays_S/ray_src153_recD109U_S.npy (path length 23)
# Saved ray src=154 rec=C101T phase=S -> rays_S/ray_src154_recC101T_S.npy (path length 16)
# Saved ray src=154 rec=C104T phase=S -> rays_S/ray_src154_recC104T_S.npy (path length 16)
# Saved ray src=154 rec=R137T phase=S -> rays_S/ray_src154_recR137T_S.npy (path length 17)
# Saved ray src=154 rec=H121T phase=S -> rays_S/ray_src154_recH121T_S.npy (path length 17)
# Saved ray src=154 rec=G121T phase=S -> rays_S/ray_src154_recG121T_S.npy (path length 17)
# Saved ray src=154 rec=C112T phase=S -> rays_S/ray_src154_recC112T_S.npy (path length 17)
# Saved ray src=154 rec=A118T phase=S -> rays_S/ray_src154_recA118T_S.npy (path length 17)
# Saved ray src=154 rec=H129T phase=S -> rays_S/ray_src154_recH129T_S.npy (path length 17)
# Saved ray src=154 rec=G129T phase=S -> rays_S/ray_src154_recG129T_S.npy (path length 17)
# Saved ray src=154 rec=H106T phase=S -> rays_S/ray_src154_recH106T_S.npy (path length 17)
# Saved ray src=154 rec=K107T phase=S -> rays_S/ray_src154_recK107T_S.npy (path length 18)
# Saved ray src=154 rec=H118T phase=S -> rays_S/ray_src154_recH118T_S.npy (path length 17)
# Saved ray src=154 rec=G118T phase=S -> rays_S/ray_src154_recG118T_S.npy (path length 17)
# Saved ray src=154 rec=A131T phase=S -> rays_S/ray_src154_recA131T_S.npy (path length 18)
# Saved ray src=154 rec=E101U phase=S -> rays_S/ray_src154_recE101U_S.npy (path length 18)
# Saved ray src=154 rec=A121T phase=S -> rays_S/ray_src154_recA121T_S.npy (path length 18)
# Saved ray src=154 rec=R110T phase=S -> rays_S/ray_src154_recR110T_S.npy (path length 18)
# Saved ray src=154 rec=R116T phase=S -> rays_S/ray_src154_recR116T_S.npy (path length 18)
# Saved ray src=154 rec=R113T phase=S -> rays_S/ray_src154_recR113T_S.npy (path length 18)
# Saved ray src=154 rec=E104U phase=S -> rays_S/ray_src154_recE104U_S.npy (path length 18)
# Saved ray src=154 rec=H110T phase=S -> rays_S/ray_src154_recH110T_S.npy (path length 18)
# Saved ray src=154 rec=G110T phase=S -> rays_S/ray_src154_recG110T_S.npy (path length 18)
# Saved ray src=154 rec=E122U phase=S -> rays_S/ray_src154_recE122U_S.npy (path length 18)
# Saved ray src=154 rec=E131U phase=S -> rays_S/ray_src154_recE131U_S.npy (path length 18)
# Saved ray src=154 rec=E128U phase=S -> rays_S/ray_src154_recE128U_S.npy (path length 18)
# Saved ray src=154 rec=R101T phase=S -> rays_S/ray_src154_recR101T_S.npy (path length 18)
# Saved ray src=154 rec=A109T phase=S -> rays_S/ray_src154_recA109T_S.npy (path length 18)
# Saved ray src=154 rec=A106T phase=S -> rays_S/ray_src154_recA106T_S.npy (path length 18)
# Saved ray src=154 rec=R122T phase=S -> rays_S/ray_src154_recR122T_S.npy (path length 18)
# Saved ray src=154 rec=B138T phase=S -> rays_S/ray_src154_recB138T_S.npy (path length 18)
# Saved ray src=154 rec=E107U phase=S -> rays_S/ray_src154_recE107U_S.npy (path length 18)
# Saved ray src=154 rec=F107T phase=S -> rays_S/ray_src154_recF107T_S.npy (path length 19)
# Saved ray src=154 rec=B135T phase=S -> rays_S/ray_src154_recB135T_S.npy (path length 18)
# Saved ray src=154 rec=F101T phase=S -> rays_S/ray_src154_recF101T_S.npy (path length 19)
# Saved ray src=154 rec=E110U phase=S -> rays_S/ray_src154_recE110U_S.npy (path length 19)
# Saved ray src=154 rec=F104T phase=S -> rays_S/ray_src154_recF104T_S.npy (path length 19)
# Saved ray src=154 rec=D101U phase=S -> rays_S/ray_src154_recD101U_S.npy (path length 19)
# Saved ray src=154 rec=D104T phase=S -> rays_S/ray_src154_recD104T_S.npy (path length 19)
# Saved ray src=154 rec=M107T phase=S -> rays_S/ray_src154_recM107T_S.npy (path length 19)
# Saved ray src=154 rec=E113U phase=S -> rays_S/ray_src154_recE113U_S.npy (path length 19)
# Saved ray src=154 rec=A101T phase=S -> rays_S/ray_src154_recA101T_S.npy (path length 19)
# Saved ray src=154 rec=M101T phase=S -> rays_S/ray_src154_recM101T_S.npy (path length 19)
# Saved ray src=154 rec=R140T phase=S -> rays_S/ray_src154_recR140T_S.npy (path length 19)
# Saved ray src=154 rec=R131T phase=S -> rays_S/ray_src154_recR131T_S.npy (path length 19)
# Saved ray src=154 rec=R128T phase=S -> rays_S/ray_src154_recR128T_S.npy (path length 20)
# Saved ray src=154 rec=D112U phase=S -> rays_S/ray_src154_recD112U_S.npy (path length 20)
# Saved ray src=154 rec=M104T phase=S -> rays_S/ray_src154_recM104T_S.npy (path length 19)
# Saved ray src=154 rec=L101U phase=S -> rays_S/ray_src154_recL101U_S.npy (path length 20)
# Saved ray src=154 rec=L113U phase=S -> rays_S/ray_src154_recL113U_S.npy (path length 21)
# Saved ray src=154 rec=L110U phase=S -> rays_S/ray_src154_recL110U_S.npy (path length 21)
# Saved ray src=155 rec=C101T phase=S -> rays_S/ray_src155_recC101T_S.npy (path length 16)
# Saved ray src=155 rec=C104T phase=S -> rays_S/ray_src155_recC104T_S.npy (path length 16)
# Saved ray src=155 rec=R137T phase=S -> rays_S/ray_src155_recR137T_S.npy (path length 17)
# Saved ray src=155 rec=A118T phase=S -> rays_S/ray_src155_recA118T_S.npy (path length 17)
# Saved ray src=155 rec=C112T phase=S -> rays_S/ray_src155_recC112T_S.npy (path length 17)
# Saved ray src=155 rec=E101U phase=S -> rays_S/ray_src155_recE101U_S.npy (path length 18)
# Saved ray src=155 rec=H121T phase=S -> rays_S/ray_src155_recH121T_S.npy (path length 17)
# Saved ray src=155 rec=G121T phase=S -> rays_S/ray_src155_recG121T_S.npy (path length 17)
# Saved ray src=155 rec=A131T phase=S -> rays_S/ray_src155_recA131T_S.npy (path length 18)
# Saved ray src=155 rec=E104U phase=S -> rays_S/ray_src155_recE104U_S.npy (path length 18)
# Saved ray src=155 rec=A121T phase=S -> rays_S/ray_src155_recA121T_S.npy (path length 18)
# Saved ray src=155 rec=G103T phase=S -> rays_S/ray_src155_recG103T_S.npy (path length 17)
# Saved ray src=155 rec=E122U phase=S -> rays_S/ray_src155_recE122U_S.npy (path length 18)
# Saved ray src=155 rec=K101T phase=S -> rays_S/ray_src155_recK101T_S.npy (path length 17)
# Saved ray src=155 rec=E131U phase=S -> rays_S/ray_src155_recE131U_S.npy (path length 18)
# Saved ray src=155 rec=E128U phase=S -> rays_S/ray_src155_recE128U_S.npy (path length 18)
# Saved ray src=155 rec=R101T phase=S -> rays_S/ray_src155_recR101T_S.npy (path length 18)
# Saved ray src=155 rec=A112T phase=S -> rays_S/ray_src155_recA112T_S.npy (path length 18)
# Saved ray src=155 rec=A124T phase=S -> rays_S/ray_src155_recA124T_S.npy (path length 18)
# Saved ray src=155 rec=H106T phase=S -> rays_S/ray_src155_recH106T_S.npy (path length 17)
# Saved ray src=155 rec=G106T phase=S -> rays_S/ray_src155_recG106T_S.npy (path length 17)
# Saved ray src=155 rec=E107U phase=S -> rays_S/ray_src155_recE107U_S.npy (path length 18)
# Saved ray src=155 rec=E119U phase=S -> rays_S/ray_src155_recE119U_S.npy (path length 18)
# Saved ray src=155 rec=K107T phase=S -> rays_S/ray_src155_recK107T_S.npy (path length 18)
# Saved ray src=155 rec=A106T phase=S -> rays_S/ray_src155_recA106T_S.npy (path length 18)
# Saved ray src=155 rec=B138T phase=S -> rays_S/ray_src155_recB138T_S.npy (path length 18)
# Saved ray src=155 rec=A109T phase=S -> rays_S/ray_src155_recA109T_S.npy (path length 18)
# Saved ray src=155 rec=G114T phase=S -> rays_S/ray_src155_recG114T_S.npy (path length 18)
# Saved ray src=155 rec=H126T phase=S -> rays_S/ray_src155_recH126T_S.npy (path length 18)
# Saved ray src=155 rec=H114T phase=S -> rays_S/ray_src155_recH114T_S.npy (path length 18)
# Saved ray src=155 rec=G126T phase=S -> rays_S/ray_src155_recG126T_S.npy (path length 18)
# Saved ray src=155 rec=E110U phase=S -> rays_S/ray_src155_recE110U_S.npy (path length 19)
# Saved ray src=155 rec=R110T phase=S -> rays_S/ray_src155_recR110T_S.npy (path length 18)
# Saved ray src=155 rec=B135T phase=S -> rays_S/ray_src155_recB135T_S.npy (path length 18)
# Saved ray src=155 rec=R116T phase=S -> rays_S/ray_src155_recR116T_S.npy (path length 18)
# Saved ray src=155 rec=R113T phase=S -> rays_S/ray_src155_recR113T_S.npy (path length 18)
# Saved ray src=155 rec=R107T phase=S -> rays_S/ray_src155_recR107T_S.npy (path length 18)
# Saved ray src=155 rec=E113U phase=S -> rays_S/ray_src155_recE113U_S.npy (path length 19)
# Saved ray src=155 rec=H110T phase=S -> rays_S/ray_src155_recH110T_S.npy (path length 18)
# Saved ray src=155 rec=G110T phase=S -> rays_S/ray_src155_recG110T_S.npy (path length 18)
# Saved ray src=155 rec=R119T phase=S -> rays_S/ray_src155_recR119T_S.npy (path length 18)
# Saved ray src=155 rec=M107T phase=S -> rays_S/ray_src155_recM107T_S.npy (path length 19)
# Saved ray src=155 rec=A101T phase=S -> rays_S/ray_src155_recA101T_S.npy (path length 19)
# Saved ray src=155 rec=R122T phase=S -> rays_S/ray_src155_recR122T_S.npy (path length 18)
# Saved ray src=155 rec=R140T phase=S -> rays_S/ray_src155_recR140T_S.npy (path length 19)
# Saved ray src=155 rec=M101T phase=S -> rays_S/ray_src155_recM101T_S.npy (path length 19)
# Saved ray src=155 rec=F107T phase=S -> rays_S/ray_src155_recF107T_S.npy (path length 19)
# Saved ray src=155 rec=M104T phase=S -> rays_S/ray_src155_recM104T_S.npy (path length 19)
# Saved ray src=155 rec=F101T phase=S -> rays_S/ray_src155_recF101T_S.npy (path length 19)
# Saved ray src=155 rec=L101U phase=S -> rays_S/ray_src155_recL101U_S.npy (path length 20)
# Saved ray src=155 rec=D101U phase=S -> rays_S/ray_src155_recD101U_S.npy (path length 19)
# Saved ray src=155 rec=D104T phase=S -> rays_S/ray_src155_recD104T_S.npy (path length 19)
# Saved ray src=155 rec=F104T phase=S -> rays_S/ray_src155_recF104T_S.npy (path length 19)
# Saved ray src=155 rec=R131T phase=S -> rays_S/ray_src155_recR131T_S.npy (path length 19)
# Saved ray src=155 rec=R128T phase=S -> rays_S/ray_src155_recR128T_S.npy (path length 20)
# Saved ray src=155 rec=D118U phase=S -> rays_S/ray_src155_recD118U_S.npy (path length 20)
# Saved ray src=155 rec=D115U phase=S -> rays_S/ray_src155_recD115U_S.npy (path length 20)
# Saved ray src=155 rec=L113U phase=S -> rays_S/ray_src155_recL113U_S.npy (path length 21)
# Saved ray src=155 rec=L110U phase=S -> rays_S/ray_src155_recL110U_S.npy (path length 21)
# Saved ray src=155 rec=R104T phase=S -> rays_S/ray_src155_recR104T_S.npy (path length 21)
# Saved ray src=155 rec=D128U phase=S -> rays_S/ray_src155_recD128U_S.npy (path length 21)
# Saved ray src=156 rec=R137T phase=S -> rays_S/ray_src156_recR137T_S.npy (path length 17)
# Saved ray src=156 rec=C101T phase=S -> rays_S/ray_src156_recC101T_S.npy (path length 16)
# Saved ray src=156 rec=C104T phase=S -> rays_S/ray_src156_recC104T_S.npy (path length 16)
# Saved ray src=156 rec=H103T phase=S -> rays_S/ray_src156_recH103T_S.npy (path length 17)
# Saved ray src=156 rec=G103T phase=S -> rays_S/ray_src156_recG103T_S.npy (path length 17)
# Saved ray src=156 rec=K101T phase=S -> rays_S/ray_src156_recK101T_S.npy (path length 17)
# Saved ray src=156 rec=A118T phase=S -> rays_S/ray_src156_recA118T_S.npy (path length 17)
# Saved ray src=156 rec=C112T phase=S -> rays_S/ray_src156_recC112T_S.npy (path length 17)
# Saved ray src=156 rec=H106T phase=S -> rays_S/ray_src156_recH106T_S.npy (path length 17)
# Saved ray src=156 rec=G106T phase=S -> rays_S/ray_src156_recG106T_S.npy (path length 17)
# Saved ray src=156 rec=K107T phase=S -> rays_S/ray_src156_recK107T_S.npy (path length 18)
# Saved ray src=156 rec=A131T phase=S -> rays_S/ray_src156_recA131T_S.npy (path length 18)
# Saved ray src=156 rec=E125U phase=S -> rays_S/ray_src156_recE125U_S.npy (path length 17)
# Saved ray src=156 rec=H126T phase=S -> rays_S/ray_src156_recH126T_S.npy (path length 18)
# Saved ray src=156 rec=G126T phase=S -> rays_S/ray_src156_recG126T_S.npy (path length 18)
# Saved ray src=156 rec=A121T phase=S -> rays_S/ray_src156_recA121T_S.npy (path length 18)
# Saved ray src=156 rec=E101U phase=S -> rays_S/ray_src156_recE101U_S.npy (path length 18)
# Saved ray src=156 rec=A112T phase=S -> rays_S/ray_src156_recA112T_S.npy (path length 18)
# Saved ray src=156 rec=R110T phase=S -> rays_S/ray_src156_recR110T_S.npy (path length 18)
# Saved ray src=156 rec=R116T phase=S -> rays_S/ray_src156_recR116T_S.npy (path length 18)
# Saved ray src=156 rec=R113T phase=S -> rays_S/ray_src156_recR113T_S.npy (path length 18)
# Saved ray src=156 rec=R107T phase=S -> rays_S/ray_src156_recR107T_S.npy (path length 18)
# Saved ray src=156 rec=E104U phase=S -> rays_S/ray_src156_recE104U_S.npy (path length 18)
# Saved ray src=156 rec=R119T phase=S -> rays_S/ray_src156_recR119T_S.npy (path length 18)
# Saved ray src=156 rec=H110T phase=S -> rays_S/ray_src156_recH110T_S.npy (path length 18)
# Saved ray src=156 rec=G110T phase=S -> rays_S/ray_src156_recG110T_S.npy (path length 18)
# Saved ray src=156 rec=E122U phase=S -> rays_S/ray_src156_recE122U_S.npy (path length 18)
# Saved ray src=156 rec=E131U phase=S -> rays_S/ray_src156_recE131U_S.npy (path length 18)
# Saved ray src=156 rec=E128U phase=S -> rays_S/ray_src156_recE128U_S.npy (path length 18)
# Saved ray src=156 rec=A109T phase=S -> rays_S/ray_src156_recA109T_S.npy (path length 18)
# Saved ray src=156 rec=R101T phase=S -> rays_S/ray_src156_recR101T_S.npy (path length 18)
# Saved ray src=156 rec=A106T phase=S -> rays_S/ray_src156_recA106T_S.npy (path length 18)
# Saved ray src=156 rec=R122T phase=S -> rays_S/ray_src156_recR122T_S.npy (path length 18)
# Saved ray src=156 rec=E107U phase=S -> rays_S/ray_src156_recE107U_S.npy (path length 18)
# Saved ray src=156 rec=B138T phase=S -> rays_S/ray_src156_recB138T_S.npy (path length 18)
# Saved ray src=156 rec=F107T phase=S -> rays_S/ray_src156_recF107T_S.npy (path length 19)
# Saved ray src=156 rec=E119U phase=S -> rays_S/ray_src156_recE119U_S.npy (path length 18)
# Saved ray src=156 rec=F101T phase=S -> rays_S/ray_src156_recF101T_S.npy (path length 19)
# Saved ray src=156 rec=B135T phase=S -> rays_S/ray_src156_recB135T_S.npy (path length 18)
# Saved ray src=156 rec=D104T phase=S -> rays_S/ray_src156_recD104T_S.npy (path length 19)
# Saved ray src=156 rec=E113U phase=S -> rays_S/ray_src156_recE113U_S.npy (path length 19)
# Saved ray src=156 rec=M107T phase=S -> rays_S/ray_src156_recM107T_S.npy (path length 19)
# Saved ray src=156 rec=A101T phase=S -> rays_S/ray_src156_recA101T_S.npy (path length 19)
# Saved ray src=156 rec=R131T phase=S -> rays_S/ray_src156_recR131T_S.npy (path length 19)
# Saved ray src=156 rec=R128T phase=S -> rays_S/ray_src156_recR128T_S.npy (path length 20)
# Saved ray src=156 rec=M101T phase=S -> rays_S/ray_src156_recM101T_S.npy (path length 19)
# Saved ray src=156 rec=R140T phase=S -> rays_S/ray_src156_recR140T_S.npy (path length 19)
# Saved ray src=156 rec=M104T phase=S -> rays_S/ray_src156_recM104T_S.npy (path length 19)
# Saved ray src=156 rec=L101U phase=S -> rays_S/ray_src156_recL101U_S.npy (path length 20)
# Saved ray src=156 rec=L113U phase=S -> rays_S/ray_src156_recL113U_S.npy (path length 21)
# Saved ray src=156 rec=L110U phase=S -> rays_S/ray_src156_recL110U_S.npy (path length 21)
# Saved ray src=157 rec=C101T phase=S -> rays_S/ray_src157_recC101T_S.npy (path length 16)
# Saved ray src=157 rec=C104T phase=S -> rays_S/ray_src157_recC104T_S.npy (path length 16)
# Saved ray src=157 rec=R137T phase=S -> rays_S/ray_src157_recR137T_S.npy (path length 17)
# Saved ray src=157 rec=C112T phase=S -> rays_S/ray_src157_recC112T_S.npy (path length 17)
# Saved ray src=157 rec=A118T phase=S -> rays_S/ray_src157_recA118T_S.npy (path length 17)
# Saved ray src=157 rec=E125U phase=S -> rays_S/ray_src157_recE125U_S.npy (path length 17)
# Saved ray src=157 rec=E101U phase=S -> rays_S/ray_src157_recE101U_S.npy (path length 18)
# Saved ray src=157 rec=H103T phase=S -> rays_S/ray_src157_recH103T_S.npy (path length 17)
# Saved ray src=157 rec=G103T phase=S -> rays_S/ray_src157_recG103T_S.npy (path length 17)
# Saved ray src=157 rec=K101T phase=S -> rays_S/ray_src157_recK101T_S.npy (path length 17)
# Saved ray src=157 rec=E104U phase=S -> rays_S/ray_src157_recE104U_S.npy (path length 18)
# Saved ray src=157 rec=E122U phase=S -> rays_S/ray_src157_recE122U_S.npy (path length 18)
# Saved ray src=157 rec=A121T phase=S -> rays_S/ray_src157_recA121T_S.npy (path length 18)
# Saved ray src=157 rec=E131U phase=S -> rays_S/ray_src157_recE131U_S.npy (path length 18)
# Saved ray src=157 rec=E128U phase=S -> rays_S/ray_src157_recE128U_S.npy (path length 18)
# Saved ray src=157 rec=H118T phase=S -> rays_S/ray_src157_recH118T_S.npy (path length 17)
# Saved ray src=157 rec=G118T phase=S -> rays_S/ray_src157_recG118T_S.npy (path length 17)
# Saved ray src=157 rec=K107T phase=S -> rays_S/ray_src157_recK107T_S.npy (path length 18)
# Saved ray src=157 rec=A112T phase=S -> rays_S/ray_src157_recA112T_S.npy (path length 18)
# Saved ray src=157 rec=R101T phase=S -> rays_S/ray_src157_recR101T_S.npy (path length 18)
# Saved ray src=157 rec=B138T phase=S -> rays_S/ray_src157_recB138T_S.npy (path length 18)
# Saved ray src=157 rec=E107U phase=S -> rays_S/ray_src157_recE107U_S.npy (path length 18)
# Saved ray src=157 rec=A109T phase=S -> rays_S/ray_src157_recA109T_S.npy (path length 18)
# Saved ray src=157 rec=R116T phase=S -> rays_S/ray_src157_recR116T_S.npy (path length 18)
# Saved ray src=157 rec=B135T phase=S -> rays_S/ray_src157_recB135T_S.npy (path length 18)
# Saved ray src=157 rec=R113T phase=S -> rays_S/ray_src157_recR113T_S.npy (path length 18)
# Saved ray src=157 rec=H110T phase=S -> rays_S/ray_src157_recH110T_S.npy (path length 18)
# Saved ray src=157 rec=G110T phase=S -> rays_S/ray_src157_recG110T_S.npy (path length 18)
# Saved ray src=157 rec=R119T phase=S -> rays_S/ray_src157_recR119T_S.npy (path length 18)
# Saved ray src=157 rec=M107T phase=S -> rays_S/ray_src157_recM107T_S.npy (path length 19)
# Saved ray src=157 rec=E113U phase=S -> rays_S/ray_src157_recE113U_S.npy (path length 19)
# Saved ray src=157 rec=R122T phase=S -> rays_S/ray_src157_recR122T_S.npy (path length 18)
# Saved ray src=157 rec=R140T phase=S -> rays_S/ray_src157_recR140T_S.npy (path length 19)
# Saved ray src=157 rec=M101T phase=S -> rays_S/ray_src157_recM101T_S.npy (path length 19)
# Saved ray src=157 rec=F107T phase=S -> rays_S/ray_src157_recF107T_S.npy (path length 19)
# Saved ray src=157 rec=A101T phase=S -> rays_S/ray_src157_recA101T_S.npy (path length 19)
# Saved ray src=157 rec=F101T phase=S -> rays_S/ray_src157_recF101T_S.npy (path length 19)
# Saved ray src=157 rec=M104T phase=S -> rays_S/ray_src157_recM104T_S.npy (path length 19)
# Saved ray src=157 rec=F104T phase=S -> rays_S/ray_src157_recF104T_S.npy (path length 19)
# Saved ray src=157 rec=L101U phase=S -> rays_S/ray_src157_recL101U_S.npy (path length 20)
# Saved ray src=157 rec=D112U phase=S -> rays_S/ray_src157_recD112U_S.npy (path length 20)
# Saved ray src=157 rec=D118U phase=S -> rays_S/ray_src157_recD118U_S.npy (path length 20)
# Saved ray src=157 rec=L113U phase=S -> rays_S/ray_src157_recL113U_S.npy (path length 21)
# Saved ray src=157 rec=L110U phase=S -> rays_S/ray_src157_recL110U_S.npy (path length 21)
# Saved ray src=157 rec=R134T phase=S -> rays_S/ray_src157_recR134T_S.npy (path length 23)
# Saved ray src=159 rec=C101T phase=S -> rays_S/ray_src159_recC101T_S.npy (path length 16)
# Saved ray src=159 rec=C104T phase=S -> rays_S/ray_src159_recC104T_S.npy (path length 16)
# Saved ray src=159 rec=R137T phase=S -> rays_S/ray_src159_recR137T_S.npy (path length 17)
# Saved ray src=159 rec=A118T phase=S -> rays_S/ray_src159_recA118T_S.npy (path length 17)
# Saved ray src=159 rec=K101T phase=S -> rays_S/ray_src159_recK101T_S.npy (path length 17)
# Saved ray src=159 rec=C112T phase=S -> rays_S/ray_src159_recC112T_S.npy (path length 17)
# Saved ray src=159 rec=A131T phase=S -> rays_S/ray_src159_recA131T_S.npy (path length 18)
# Saved ray src=159 rec=E125U phase=S -> rays_S/ray_src159_recE125U_S.npy (path length 17)
# Saved ray src=159 rec=E101U phase=S -> rays_S/ray_src159_recE101U_S.npy (path length 18)
# Saved ray src=159 rec=A121T phase=S -> rays_S/ray_src159_recA121T_S.npy (path length 18)
# Saved ray src=159 rec=A112T phase=S -> rays_S/ray_src159_recA112T_S.npy (path length 18)
# Saved ray src=159 rec=E104U phase=S -> rays_S/ray_src159_recE104U_S.npy (path length 18)
# Saved ray src=159 rec=H126T phase=S -> rays_S/ray_src159_recH126T_S.npy (path length 18)
# Saved ray src=159 rec=G126T phase=S -> rays_S/ray_src159_recG126T_S.npy (path length 18)
# Saved ray src=159 rec=A124T phase=S -> rays_S/ray_src159_recA124T_S.npy (path length 18)
# Saved ray src=159 rec=R110T phase=S -> rays_S/ray_src159_recR110T_S.npy (path length 18)
# Saved ray src=159 rec=E122U phase=S -> rays_S/ray_src159_recE122U_S.npy (path length 18)
# Saved ray src=159 rec=E131U phase=S -> rays_S/ray_src159_recE131U_S.npy (path length 18)
# Saved ray src=159 rec=E128U phase=S -> rays_S/ray_src159_recE128U_S.npy (path length 18)
# Saved ray src=159 rec=R116T phase=S -> rays_S/ray_src159_recR116T_S.npy (path length 18)
# Saved ray src=159 rec=R113T phase=S -> rays_S/ray_src159_recR113T_S.npy (path length 18)
# Saved ray src=159 rec=R101T phase=S -> rays_S/ray_src159_recR101T_S.npy (path length 18)
# Saved ray src=159 rec=R107T phase=S -> rays_S/ray_src159_recR107T_S.npy (path length 18)
# Saved ray src=159 rec=A109T phase=S -> rays_S/ray_src159_recA109T_S.npy (path length 18)
# Saved ray src=159 rec=A106T phase=S -> rays_S/ray_src159_recA106T_S.npy (path length 18)
# Saved ray src=159 rec=R119T phase=S -> rays_S/ray_src159_recR119T_S.npy (path length 18)
# Saved ray src=159 rec=H110T phase=S -> rays_S/ray_src159_recH110T_S.npy (path length 18)
# Saved ray src=159 rec=G110T phase=S -> rays_S/ray_src159_recG110T_S.npy (path length 18)
# Saved ray src=159 rec=E107U phase=S -> rays_S/ray_src159_recE107U_S.npy (path length 18)
# Saved ray src=159 rec=E119U phase=S -> rays_S/ray_src159_recE119U_S.npy (path length 18)
# Saved ray src=159 rec=B138T phase=S -> rays_S/ray_src159_recB138T_S.npy (path length 18)
# Saved ray src=159 rec=R122T phase=S -> rays_S/ray_src159_recR122T_S.npy (path length 18)
# Saved ray src=159 rec=F107T phase=S -> rays_S/ray_src159_recF107T_S.npy (path length 19)
# Saved ray src=159 rec=E110U phase=S -> rays_S/ray_src159_recE110U_S.npy (path length 19)
# Saved ray src=159 rec=B135T phase=S -> rays_S/ray_src159_recB135T_S.npy (path length 18)
# Saved ray src=159 rec=E113U phase=S -> rays_S/ray_src159_recE113U_S.npy (path length 19)
# Saved ray src=159 rec=F101T phase=S -> rays_S/ray_src159_recF101T_S.npy (path length 19)
# Saved ray src=159 rec=A101T phase=S -> rays_S/ray_src159_recA101T_S.npy (path length 19)
# Saved ray src=159 rec=M107T phase=S -> rays_S/ray_src159_recM107T_S.npy (path length 19)
# Saved ray src=159 rec=F104T phase=S -> rays_S/ray_src159_recF104T_S.npy (path length 19)
# Saved ray src=159 rec=D125U phase=S -> rays_S/ray_src159_recD125U_S.npy (path length 19)
# Saved ray src=159 rec=D104T phase=S -> rays_S/ray_src159_recD104T_S.npy (path length 19)
# Saved ray src=159 rec=R140T phase=S -> rays_S/ray_src159_recR140T_S.npy (path length 19)
# Saved ray src=159 rec=M101T phase=S -> rays_S/ray_src159_recM101T_S.npy (path length 19)
# Saved ray src=159 rec=R131T phase=S -> rays_S/ray_src159_recR131T_S.npy (path length 19)
# Saved ray src=159 rec=R128T phase=S -> rays_S/ray_src159_recR128T_S.npy (path length 20)
# Saved ray src=159 rec=M104T phase=S -> rays_S/ray_src159_recM104T_S.npy (path length 19)
# Saved ray src=159 rec=D118U phase=S -> rays_S/ray_src159_recD118U_S.npy (path length 20)
# Saved ray src=159 rec=L101U phase=S -> rays_S/ray_src159_recL101U_S.npy (path length 20)
# Saved ray src=159 rec=D115U phase=S -> rays_S/ray_src159_recD115U_S.npy (path length 20)
# Saved ray src=159 rec=L113U phase=S -> rays_S/ray_src159_recL113U_S.npy (path length 21)
# Saved ray src=159 rec=L110U phase=S -> rays_S/ray_src159_recL110U_S.npy (path length 21)
# Saved ray src=160 rec=R137T phase=S -> rays_S/ray_src160_recR137T_S.npy (path length 17)
# Saved ray src=160 rec=A118T phase=S -> rays_S/ray_src160_recA118T_S.npy (path length 17)
# Saved ray src=160 rec=C101T phase=S -> rays_S/ray_src160_recC101T_S.npy (path length 16)
# Saved ray src=160 rec=C104T phase=S -> rays_S/ray_src160_recC104T_S.npy (path length 16)
# Saved ray src=160 rec=K101T phase=S -> rays_S/ray_src160_recK101T_S.npy (path length 17)
# Saved ray src=160 rec=A112T phase=S -> rays_S/ray_src160_recA112T_S.npy (path length 18)
# Saved ray src=160 rec=A121T phase=S -> rays_S/ray_src160_recA121T_S.npy (path length 18)
# Saved ray src=160 rec=K107T phase=S -> rays_S/ray_src160_recK107T_S.npy (path length 18)
# Saved ray src=160 rec=C112T phase=S -> rays_S/ray_src160_recC112T_S.npy (path length 17)
# Saved ray src=160 rec=R110T phase=S -> rays_S/ray_src160_recR110T_S.npy (path length 18)
# Saved ray src=160 rec=E101U phase=S -> rays_S/ray_src160_recE101U_S.npy (path length 18)
# Saved ray src=160 rec=R107T phase=S -> rays_S/ray_src160_recR107T_S.npy (path length 18)
# Saved ray src=160 rec=A109T phase=S -> rays_S/ray_src160_recA109T_S.npy (path length 18)
# Saved ray src=160 rec=H126T phase=S -> rays_S/ray_src160_recH126T_S.npy (path length 18)
# Saved ray src=160 rec=G126T phase=S -> rays_S/ray_src160_recG126T_S.npy (path length 18)
# Saved ray src=160 rec=R116T phase=S -> rays_S/ray_src160_recR116T_S.npy (path length 18)
# Saved ray src=160 rec=E104U phase=S -> rays_S/ray_src160_recE104U_S.npy (path length 18)
# Saved ray src=160 rec=A106T phase=S -> rays_S/ray_src160_recA106T_S.npy (path length 18)
# Saved ray src=160 rec=E131U phase=S -> rays_S/ray_src160_recE131U_S.npy (path length 18)
# Saved ray src=160 rec=E128U phase=S -> rays_S/ray_src160_recE128U_S.npy (path length 18)
# Saved ray src=160 rec=E122U phase=S -> rays_S/ray_src160_recE122U_S.npy (path length 18)
# Saved ray src=160 rec=H110T phase=S -> rays_S/ray_src160_recH110T_S.npy (path length 18)
# Saved ray src=160 rec=G110T phase=S -> rays_S/ray_src160_recG110T_S.npy (path length 18)
# Saved ray src=160 rec=E107U phase=S -> rays_S/ray_src160_recE107U_S.npy (path length 18)
# Saved ray src=160 rec=R122T phase=S -> rays_S/ray_src160_recR122T_S.npy (path length 18)
# Saved ray src=160 rec=E119U phase=S -> rays_S/ray_src160_recE119U_S.npy (path length 18)
# Saved ray src=160 rec=F107T phase=S -> rays_S/ray_src160_recF107T_S.npy (path length 19)
# Saved ray src=160 rec=B138T phase=S -> rays_S/ray_src160_recB138T_S.npy (path length 18)
# Saved ray src=160 rec=A101T phase=S -> rays_S/ray_src160_recA101T_S.npy (path length 19)
# Saved ray src=160 rec=F101T phase=S -> rays_S/ray_src160_recF101T_S.npy (path length 19)
# Saved ray src=160 rec=B135T phase=S -> rays_S/ray_src160_recB135T_S.npy (path length 18)
# Saved ray src=160 rec=E113U phase=S -> rays_S/ray_src160_recE113U_S.npy (path length 19)
# Saved ray src=160 rec=R131T phase=S -> rays_S/ray_src160_recR131T_S.npy (path length 19)
# Saved ray src=160 rec=R128T phase=S -> rays_S/ray_src160_recR128T_S.npy (path length 20)
# Saved ray src=160 rec=D104T phase=S -> rays_S/ray_src160_recD104T_S.npy (path length 19)
# Saved ray src=160 rec=M107T phase=S -> rays_S/ray_src160_recM107T_S.npy (path length 19)
# Saved ray src=160 rec=R140T phase=S -> rays_S/ray_src160_recR140T_S.npy (path length 19)
# Saved ray src=160 rec=L101U phase=S -> rays_S/ray_src160_recL101U_S.npy (path length 20)
# Saved ray src=160 rec=D115U phase=S -> rays_S/ray_src160_recD115U_S.npy (path length 20)
# Saved ray src=160 rec=L113U phase=S -> rays_S/ray_src160_recL113U_S.npy (path length 21)
# Saved ray src=160 rec=L110U phase=S -> rays_S/ray_src160_recL110U_S.npy (path length 21)
# Saved ray src=161 rec=R137T phase=S -> rays_S/ray_src161_recR137T_S.npy (path length 17)
# Saved ray src=161 rec=C101T phase=S -> rays_S/ray_src161_recC101T_S.npy (path length 16)
# Saved ray src=161 rec=C104T phase=S -> rays_S/ray_src161_recC104T_S.npy (path length 16)
# Saved ray src=161 rec=A118T phase=S -> rays_S/ray_src161_recA118T_S.npy (path length 17)
# Saved ray src=161 rec=H103T phase=S -> rays_S/ray_src161_recH103T_S.npy (path length 17)
# Saved ray src=161 rec=G103T phase=S -> rays_S/ray_src161_recG103T_S.npy (path length 17)
# Saved ray src=161 rec=H121T phase=S -> rays_S/ray_src161_recH121T_S.npy (path length 17)
# Saved ray src=161 rec=G121T phase=S -> rays_S/ray_src161_recG121T_S.npy (path length 17)
# Saved ray src=161 rec=K101T phase=S -> rays_S/ray_src161_recK101T_S.npy (path length 17)
# Saved ray src=161 rec=C112T phase=S -> rays_S/ray_src161_recC112T_S.npy (path length 17)
# Saved ray src=161 rec=H106T phase=S -> rays_S/ray_src161_recH106T_S.npy (path length 17)
# Saved ray src=161 rec=A121T phase=S -> rays_S/ray_src161_recA121T_S.npy (path length 18)
# Saved ray src=161 rec=A112T phase=S -> rays_S/ray_src161_recA112T_S.npy (path length 18)
# Saved ray src=161 rec=H126T phase=S -> rays_S/ray_src161_recH126T_S.npy (path length 18)
# Saved ray src=161 rec=G126T phase=S -> rays_S/ray_src161_recG126T_S.npy (path length 18)
# Saved ray src=161 rec=R107T phase=S -> rays_S/ray_src161_recR107T_S.npy (path length 18)
# Saved ray src=161 rec=R113T phase=S -> rays_S/ray_src161_recR113T_S.npy (path length 18)
# Saved ray src=161 rec=R116T phase=S -> rays_S/ray_src161_recR116T_S.npy (path length 18)
# Saved ray src=161 rec=R119T phase=S -> rays_S/ray_src161_recR119T_S.npy (path length 18)
# ...
# Saved ray src=239 rec=M104T phase=S -> rays_S/ray_src239_recM104T_S.npy (path length 19)
# Saved ray src=239 rec=D118U phase=S -> rays_S/ray_src239_recD118U_S.npy (path length 20)
# Saved ray src=239 rec=D115U phase=S -> rays_S/ray_src239_recD115U_S.npy (path length 20)
# Saved ray src=239 rec=D109U phase=S -> rays_S/ray_src239_recD109U_S.npy (path length 20)
# Saved ray src=239 rec=L101U phase=S -> rays_S/ray_src239_recL101U_S.npy (path length 20)
# Saved ray src=239 rec=R134T phase=S -> rays_S/ray_src239_recR134T_S.npy (path length 23)
# Saved ray src=240 rec=R137T phase=S -> rays_S/ray_src240_recR137T_S.npy (path length 17)
# Saved ray src=240 rec=C101T phase=S -> rays_S/ray_src240_recC101T_S.npy (path length 16)
# Saved ray src=240 rec=C104T phase=S -> rays_S/ray_src240_recC104T_S.npy (path length 16)
# Saved ray src=240 rec=H121T phase=S -> rays_S/ray_src240_recH121T_S.npy (path length 17)
# Saved ray src=240 rec=G121T phase=S -> rays_S/ray_src240_recG121T_S.npy (path length 17)
# Saved ray src=240 rec=H103T phase=S -> rays_S/ray_src240_recH103T_S.npy (path length 17)
# Saved ray src=240 rec=G103T phase=S -> rays_S/ray_src240_recG103T_S.npy (path length 17)
# Saved ray src=240 rec=K101T phase=S -> rays_S/ray_src240_recK101T_S.npy (path length 17)
# Saved ray src=240 rec=C112T phase=S -> rays_S/ray_src240_recC112T_S.npy (path length 17)
# Saved ray src=240 rec=H106T phase=S -> rays_S/ray_src240_recH106T_S.npy (path length 17)
# Saved ray src=240 rec=G106T phase=S -> rays_S/ray_src240_recG106T_S.npy (path length 17)
# Saved ray src=240 rec=K107T phase=S -> rays_S/ray_src240_recK107T_S.npy (path length 18)
# Saved ray src=240 rec=A131T phase=S -> rays_S/ray_src240_recA131T_S.npy (path length 18)
# Saved ray src=240 rec=H114T phase=S -> rays_S/ray_src240_recH114T_S.npy (path length 18)
# Saved ray src=240 rec=E125U phase=S -> rays_S/ray_src240_recE125U_S.npy (path length 17)
# Saved ray src=240 rec=R110T phase=S -> rays_S/ray_src240_recR110T_S.npy (path length 18)
# Saved ray src=240 rec=A121T phase=S -> rays_S/ray_src240_recA121T_S.npy (path length 18)
# Saved ray src=240 rec=R116T phase=S -> rays_S/ray_src240_recR116T_S.npy (path length 18)
# Saved ray src=240 rec=E101U phase=S -> rays_S/ray_src240_recE101U_S.npy (path length 18)
# Saved ray src=240 rec=A112T phase=S -> rays_S/ray_src240_recA112T_S.npy (path length 18)
# Saved ray src=240 rec=R107T phase=S -> rays_S/ray_src240_recR107T_S.npy (path length 18)
# Saved ray src=240 rec=R119T phase=S -> rays_S/ray_src240_recR119T_S.npy (path length 18)
# Saved ray src=240 rec=H110T phase=S -> rays_S/ray_src240_recH110T_S.npy (path length 18)
# Saved ray src=240 rec=G110T phase=S -> rays_S/ray_src240_recG110T_S.npy (path length 18)
# Saved ray src=240 rec=E104U phase=S -> rays_S/ray_src240_recE104U_S.npy (path length 18)
# Saved ray src=240 rec=E122U phase=S -> rays_S/ray_src240_recE122U_S.npy (path length 18)
# Saved ray src=240 rec=E131U phase=S -> rays_S/ray_src240_recE131U_S.npy (path length 18)
# Saved ray src=240 rec=E128U phase=S -> rays_S/ray_src240_recE128U_S.npy (path length 18)
# Saved ray src=240 rec=A109T phase=S -> rays_S/ray_src240_recA109T_S.npy (path length 18)
# Saved ray src=240 rec=R101T phase=S -> rays_S/ray_src240_recR101T_S.npy (path length 18)
# Saved ray src=240 rec=R122T phase=S -> rays_S/ray_src240_recR122T_S.npy (path length 18)
# Saved ray src=240 rec=A106T phase=S -> rays_S/ray_src240_recA106T_S.npy (path length 18)
# Saved ray src=240 rec=F107T phase=S -> rays_S/ray_src240_recF107T_S.npy (path length 19)
# Saved ray src=240 rec=B138T phase=S -> rays_S/ray_src240_recB138T_S.npy (path length 18)
# Saved ray src=240 rec=E107U phase=S -> rays_S/ray_src240_recE107U_S.npy (path length 18)
# Saved ray src=240 rec=E119U phase=S -> rays_S/ray_src240_recE119U_S.npy (path length 18)
# Saved ray src=240 rec=F101T phase=S -> rays_S/ray_src240_recF101T_S.npy (path length 19)
# Saved ray src=240 rec=B135T phase=S -> rays_S/ray_src240_recB135T_S.npy (path length 18)
# Saved ray src=240 rec=F104T phase=S -> rays_S/ray_src240_recF104T_S.npy (path length 19)
# Saved ray src=240 rec=D101U phase=S -> rays_S/ray_src240_recD101U_S.npy (path length 19)
# Saved ray src=240 rec=D104T phase=S -> rays_S/ray_src240_recD104T_S.npy (path length 19)
# Saved ray src=240 rec=M107T phase=S -> rays_S/ray_src240_recM107T_S.npy (path length 19)
# Saved ray src=240 rec=E113U phase=S -> rays_S/ray_src240_recE113U_S.npy (path length 19)
# Saved ray src=240 rec=R131T phase=S -> rays_S/ray_src240_recR131T_S.npy (path length 19)
# Saved ray src=240 rec=R128T phase=S -> rays_S/ray_src240_recR128T_S.npy (path length 20)
# Saved ray src=240 rec=A101T phase=S -> rays_S/ray_src240_recA101T_S.npy (path length 19)
# Saved ray src=240 rec=M101T phase=S -> rays_S/ray_src240_recM101T_S.npy (path length 19)
# Saved ray src=240 rec=R140T phase=S -> rays_S/ray_src240_recR140T_S.npy (path length 19)
# Saved ray src=240 rec=D118U phase=S -> rays_S/ray_src240_recD118U_S.npy (path length 20)
# Saved ray src=240 rec=D115U phase=S -> rays_S/ray_src240_recD115U_S.npy (path length 20)
# Saved ray src=240 rec=M104T phase=S -> rays_S/ray_src240_recM104T_S.npy (path length 19)
# Saved ray src=240 rec=L101U phase=S -> rays_S/ray_src240_recL101U_S.npy (path length 20)
# Saved ray src=240 rec=D128U phase=S -> rays_S/ray_src240_recD128U_S.npy (path length 21)
# Saved ray src=240 rec=L113U phase=S -> rays_S/ray_src240_recL113U_S.npy (path length 21)
# Saved ray src=240 rec=L110U phase=S -> rays_S/ray_src240_recL110U_S.npy (path length 21)
# Saved ray src=240 rec=R134T phase=S -> rays_S/ray_src240_recR134T_S.npy (path length 23)
# Saved ray src=241 rec=C101T phase=S -> rays_S/ray_src241_recC101T_S.npy (path length 16)
# Saved ray src=241 rec=C104T phase=S -> rays_S/ray_src241_recC104T_S.npy (path length 16)
# Saved ray src=241 rec=R137T phase=S -> rays_S/ray_src241_recR137T_S.npy (path length 17)
# Saved ray src=241 rec=H121T phase=S -> rays_S/ray_src241_recH121T_S.npy (path length 17)
# Saved ray src=241 rec=G121T phase=S -> rays_S/ray_src241_recG121T_S.npy (path length 17)
# Saved ray src=241 rec=H103T phase=S -> rays_S/ray_src241_recH103T_S.npy (path length 17)
# Saved ray src=241 rec=G103T phase=S -> rays_S/ray_src241_recG103T_S.npy (path length 17)
# Saved ray src=241 rec=K101T phase=S -> rays_S/ray_src241_recK101T_S.npy (path length 17)
# Saved ray src=241 rec=C112T phase=S -> rays_S/ray_src241_recC112T_S.npy (path length 17)
# Saved ray src=241 rec=H129T phase=S -> rays_S/ray_src241_recH129T_S.npy (path length 17)
# Saved ray src=241 rec=G129T phase=S -> rays_S/ray_src241_recG129T_S.npy (path length 17)
# Saved ray src=241 rec=A118T phase=S -> rays_S/ray_src241_recA118T_S.npy (path length 17)
# Saved ray src=241 rec=H106T phase=S -> rays_S/ray_src241_recH106T_S.npy (path length 17)
# Saved ray src=241 rec=G106T phase=S -> rays_S/ray_src241_recG106T_S.npy (path length 17)
# Saved ray src=241 rec=H118T phase=S -> rays_S/ray_src241_recH118T_S.npy (path length 17)
# Saved ray src=241 rec=G118T phase=S -> rays_S/ray_src241_recG118T_S.npy (path length 17)
# Saved ray src=241 rec=K107T phase=S -> rays_S/ray_src241_recK107T_S.npy (path length 18)
# Saved ray src=241 rec=H126T phase=S -> rays_S/ray_src241_recH126T_S.npy (path length 18)
# Saved ray src=241 rec=G126T phase=S -> rays_S/ray_src241_recG126T_S.npy (path length 18)
# Saved ray src=241 rec=G114T phase=S -> rays_S/ray_src241_recG114T_S.npy (path length 18)
# Saved ray src=241 rec=H114T phase=S -> rays_S/ray_src241_recH114T_S.npy (path length 18)
# Saved ray src=241 rec=E125U phase=S -> rays_S/ray_src241_recE125U_S.npy (path length 17)
# Saved ray src=241 rec=A131T phase=S -> rays_S/ray_src241_recA131T_S.npy (path length 18)
# Saved ray src=241 rec=E101U phase=S -> rays_S/ray_src241_recE101U_S.npy (path length 18)
# Saved ray src=241 rec=R116T phase=S -> rays_S/ray_src241_recR116T_S.npy (path length 18)
# Saved ray src=241 rec=A121T phase=S -> rays_S/ray_src241_recA121T_S.npy (path length 18)
# Saved ray src=241 rec=A128T phase=S -> rays_S/ray_src241_recA128T_S.npy (path length 18)
# Saved ray src=241 rec=R110T phase=S -> rays_S/ray_src241_recR110T_S.npy (path length 18)
# Saved ray src=241 rec=R113T phase=S -> rays_S/ray_src241_recR113T_S.npy (path length 18)
# Saved ray src=241 rec=A112T phase=S -> rays_S/ray_src241_recA112T_S.npy (path length 18)
# Saved ray src=241 rec=H110T phase=S -> rays_S/ray_src241_recH110T_S.npy (path length 18)
# Saved ray src=241 rec=G110T phase=S -> rays_S/ray_src241_recG110T_S.npy (path length 18)
# Saved ray src=241 rec=R119T phase=S -> rays_S/ray_src241_recR119T_S.npy (path length 18)
# Saved ray src=241 rec=E104U phase=S -> rays_S/ray_src241_recE104U_S.npy (path length 18)
# Saved ray src=241 rec=R107T phase=S -> rays_S/ray_src241_recR107T_S.npy (path length 18)
# Saved ray src=241 rec=E122U phase=S -> rays_S/ray_src241_recE122U_S.npy (path length 18)
# Saved ray src=241 rec=A124T phase=S -> rays_S/ray_src241_recA124T_S.npy (path length 18)
# Saved ray src=241 rec=E131U phase=S -> rays_S/ray_src241_recE131U_S.npy (path length 18)
# Saved ray src=241 rec=E128U phase=S -> rays_S/ray_src241_recE128U_S.npy (path length 18)
# Saved ray src=241 rec=R122T phase=S -> rays_S/ray_src241_recR122T_S.npy (path length 18)
# Saved ray src=241 rec=R101T phase=S -> rays_S/ray_src241_recR101T_S.npy (path length 18)
# Saved ray src=241 rec=A109T phase=S -> rays_S/ray_src241_recA109T_S.npy (path length 18)
# Saved ray src=241 rec=A106T phase=S -> rays_S/ray_src241_recA106T_S.npy (path length 18)
# Saved ray src=241 rec=B138T phase=S -> rays_S/ray_src241_recB138T_S.npy (path length 18)
# Saved ray src=241 rec=F107T phase=S -> rays_S/ray_src241_recF107T_S.npy (path length 19)
# Saved ray src=241 rec=E107U phase=S -> rays_S/ray_src241_recE107U_S.npy (path length 18)
# Saved ray src=241 rec=E119U phase=S -> rays_S/ray_src241_recE119U_S.npy (path length 18)
# Saved ray src=241 rec=B135T phase=S -> rays_S/ray_src241_recB135T_S.npy (path length 18)
# Saved ray src=241 rec=F101T phase=S -> rays_S/ray_src241_recF101T_S.npy (path length 19)
# Saved ray src=241 rec=E110U phase=S -> rays_S/ray_src241_recE110U_S.npy (path length 19)
# Saved ray src=241 rec=F104T phase=S -> rays_S/ray_src241_recF104T_S.npy (path length 19)
# Saved ray src=241 rec=D101U phase=S -> rays_S/ray_src241_recD101U_S.npy (path length 19)
# Saved ray src=241 rec=D104T phase=S -> rays_S/ray_src241_recD104T_S.npy (path length 19)
# Saved ray src=241 rec=M107T phase=S -> rays_S/ray_src241_recM107T_S.npy (path length 19)
# Saved ray src=241 rec=M101T phase=S -> rays_S/ray_src241_recM101T_S.npy (path length 19)
# Saved ray src=241 rec=R140T phase=S -> rays_S/ray_src241_recR140T_S.npy (path length 19)
# Saved ray src=241 rec=R131T phase=S -> rays_S/ray_src241_recR131T_S.npy (path length 19)
# Saved ray src=241 rec=R128T phase=S -> rays_S/ray_src241_recR128T_S.npy (path length 20)
# Saved ray src=241 rec=A101T phase=S -> rays_S/ray_src241_recA101T_S.npy (path length 19)
# Saved ray src=241 rec=D118U phase=S -> rays_S/ray_src241_recD118U_S.npy (path length 20)
# Saved ray src=241 rec=M104T phase=S -> rays_S/ray_src241_recM104T_S.npy (path length 19)
# Saved ray src=241 rec=D115U phase=S -> rays_S/ray_src241_recD115U_S.npy (path length 20)
# Saved ray src=241 rec=D109U phase=S -> rays_S/ray_src241_recD109U_S.npy (path length 20)
# Saved ray src=241 rec=L101U phase=S -> rays_S/ray_src241_recL101U_S.npy (path length 20)
# Saved ray src=241 rec=D128U phase=S -> rays_S/ray_src241_recD128U_S.npy (path length 21)
# Saved ray src=241 rec=L113U phase=S -> rays_S/ray_src241_recL113U_S.npy (path length 21)
# Saved ray src=241 rec=L110U phase=S -> rays_S/ray_src241_recL110U_S.npy (path length 21)
# Saved ray src=241 rec=R134T phase=S -> rays_S/ray_src241_recR134T_S.npy (path length 23)
# Saved ray src=242 rec=R137T phase=S -> rays_S/ray_src242_recR137T_S.npy (path length 17)
# Saved ray src=242 rec=C101T phase=S -> rays_S/ray_src242_recC101T_S.npy (path length 16)
# Saved ray src=242 rec=C104T phase=S -> rays_S/ray_src242_recC104T_S.npy (path length 16)
# Saved ray src=242 rec=H121T phase=S -> rays_S/ray_src242_recH121T_S.npy (path length 17)
# Saved ray src=242 rec=A118T phase=S -> rays_S/ray_src242_recA118T_S.npy (path length 17)
# Saved ray src=242 rec=G103T phase=S -> rays_S/ray_src242_recG103T_S.npy (path length 17)
# Saved ray src=242 rec=H103T phase=S -> rays_S/ray_src242_recH103T_S.npy (path length 17)
# Saved ray src=242 rec=K101T phase=S -> rays_S/ray_src242_recK101T_S.npy (path length 17)
# Saved ray src=242 rec=C112T phase=S -> rays_S/ray_src242_recC112T_S.npy (path length 17)
# Saved ray src=242 rec=H106T phase=S -> rays_S/ray_src242_recH106T_S.npy (path length 17)
# Saved ray src=242 rec=G106T phase=S -> rays_S/ray_src242_recG106T_S.npy (path length 17)
# Saved ray src=242 rec=A131T phase=S -> rays_S/ray_src242_recA131T_S.npy (path length 18)
# Saved ray src=242 rec=K107T phase=S -> rays_S/ray_src242_recK107T_S.npy (path length 18)
# Saved ray src=242 rec=E125U phase=S -> rays_S/ray_src242_recE125U_S.npy (path length 17)
# Saved ray src=242 rec=A121T phase=S -> rays_S/ray_src242_recA121T_S.npy (path length 18)
# Saved ray src=242 rec=E101U phase=S -> rays_S/ray_src242_recE101U_S.npy (path length 18)
# Saved ray src=242 rec=A112T phase=S -> rays_S/ray_src242_recA112T_S.npy (path length 18)
# Saved ray src=242 rec=H126T phase=S -> rays_S/ray_src242_recH126T_S.npy (path length 18)
# Saved ray src=242 rec=G126T phase=S -> rays_S/ray_src242_recG126T_S.npy (path length 18)
# Saved ray src=242 rec=G114T phase=S -> rays_S/ray_src242_recG114T_S.npy (path length 18)
# Saved ray src=242 rec=H114T phase=S -> rays_S/ray_src242_recH114T_S.npy (path length 18)
# Saved ray src=242 rec=E104U phase=S -> rays_S/ray_src242_recE104U_S.npy (path length 18)
# Saved ray src=242 rec=R116T phase=S -> rays_S/ray_src242_recR116T_S.npy (path length 18)
# Saved ray src=242 rec=R113T phase=S -> rays_S/ray_src242_recR113T_S.npy (path length 18)
# Saved ray src=242 rec=R107T phase=S -> rays_S/ray_src242_recR107T_S.npy (path length 18)
# Saved ray src=242 rec=E122U phase=S -> rays_S/ray_src242_recE122U_S.npy (path length 18)
# Saved ray src=242 rec=E131U phase=S -> rays_S/ray_src242_recE131U_S.npy (path length 18)
# Saved ray src=242 rec=E128U phase=S -> rays_S/ray_src242_recE128U_S.npy (path length 18)
# Saved ray src=242 rec=R119T phase=S -> rays_S/ray_src242_recR119T_S.npy (path length 18)
# Saved ray src=242 rec=H110T phase=S -> rays_S/ray_src242_recH110T_S.npy (path length 18)
# Saved ray src=242 rec=G110T phase=S -> rays_S/ray_src242_recG110T_S.npy (path length 18)
# Saved ray src=242 rec=A109T phase=S -> rays_S/ray_src242_recA109T_S.npy (path length 18)
# Saved ray src=242 rec=A106T phase=S -> rays_S/ray_src242_recA106T_S.npy (path length 18)
# Saved ray src=242 rec=R122T phase=S -> rays_S/ray_src242_recR122T_S.npy (path length 18)
# Saved ray src=242 rec=E107U phase=S -> rays_S/ray_src242_recE107U_S.npy (path length 18)
# Saved ray src=242 rec=B138T phase=S -> rays_S/ray_src242_recB138T_S.npy (path length 18)
# Saved ray src=242 rec=F107T phase=S -> rays_S/ray_src242_recF107T_S.npy (path length 19)
# Saved ray src=242 rec=F110T phase=S -> rays_S/ray_src242_recF110T_S.npy (path length 19)
# Saved ray src=242 rec=B135T phase=S -> rays_S/ray_src242_recB135T_S.npy (path length 18)
# Saved ray src=242 rec=F101T phase=S -> rays_S/ray_src242_recF101T_S.npy (path length 19)
# Saved ray src=242 rec=M107T phase=S -> rays_S/ray_src242_recM107T_S.npy (path length 19)
# Saved ray src=242 rec=F104T phase=S -> rays_S/ray_src242_recF104T_S.npy (path length 19)
# Saved ray src=242 rec=D101U phase=S -> rays_S/ray_src242_recD101U_S.npy (path length 19)
# Saved ray src=242 rec=R128T phase=S -> rays_S/ray_src242_recR128T_S.npy (path length 20)
# Saved ray src=242 rec=M101T phase=S -> rays_S/ray_src242_recM101T_S.npy (path length 19)
# Saved ray src=242 rec=R140T phase=S -> rays_S/ray_src242_recR140T_S.npy (path length 19)
# Saved ray src=242 rec=M104T phase=S -> rays_S/ray_src242_recM104T_S.npy (path length 19)
# Saved ray src=242 rec=L101U phase=S -> rays_S/ray_src242_recL101U_S.npy (path length 20)
# Saved ray src=242 rec=D109U phase=S -> rays_S/ray_src242_recD109U_S.npy (path length 20)
# P rays saved: 23989 P failures: 1
# S rays saved: 12696 S failures: 1

# %%
import numpy as np
import scipy.sparse as sp
from collections import defaultdict
from tqdm import tqdm  # optional progress bar; install with `pip install tqdm`


def _cell_index_from_point(pt, min_coords, intervals, ncx, ncy, ncz):
    """
    Return (ix,iy,iz) cell index for point pt. If point lies on the max boundary,
    clip to the last cell. Returns None if point outside domain.
    """
    rel = (pt - min_coords) / intervals
    ix = int(np.floor(rel[0]))
    iy = int(np.floor(rel[1]))
    iz = int(np.floor(rel[2]))
    if ix < 0 or ix >= ncx or iy < 0 or iy >= ncy or iz < 0 or iz >= ncz:
        return None
    return ix, iy, iz


def build_G_from_rays(rays_saved, grid_params, subdivisions=20, verbose=False):
    """
    Build sparse sensitivity matrix G for slowness-per-cell from ray paths.

    Args
    ----
    rays_saved : list of dicts
        Each dict contains at least "ray" (an Nx3 array) and optionally "phase","src","rec".
        The ordering of rays_saved defines observation index i (0..Nobs-1).
    grid_params : dict
        dict with keys: min_coords (tuple), node_intervals (tuple), npts (tuple)
        (same as used for building your solver). We interpret model cells = npts - 1.
    subdivisions : int
        Number of sub-samples per ray segment used to approximate segment-cell lengths.
        Increase for higher accuracy (cost ∝ subdivisions).
    Returns
    -------
    G : scipy.sparse.csr_matrix shape (Nobs, M)
        Sensitivity matrix where G[i,j] = path length of ray i inside cell j.
        Cell indexing uses j = ix + iy*ncx + iz*ncx*ncy (0-based).
    meta : dict
        metadata: {'Nobs', 'ncx','ncy','ncz','M','min_coords','intervals'}
    """
    min_coords = np.asarray(grid_params["min_coords"], dtype=float)
    intervals = np.asarray(grid_params["node_intervals"], dtype=float)
    npts = np.asarray(grid_params["npts"], dtype=int)
    nx, ny, nz = npts
    ncx, ncy, ncz = nx - 1, ny - 1, nz - 1
    if ncx <= 0 or ncy <= 0 or ncz <= 0:
        raise ValueError("npts must be at least 2 in each dimension to form cells")

    Nobs = len(rays_saved)
    M = ncx * ncy * ncz

    # accumulate triples lists
    row_idx = []
    col_idx = []
    data_vals = []

    it = enumerate(rays_saved)
    if verbose:
        it = tqdm(it, total=Nobs, desc="Building G")

    for i, rec in it:
        ray = np.asarray(rec["ray"], dtype=float)
        if ray.shape[0] < 2:
            # degenerate
            continue

        # For each consecutive segment, subdivide and assign samples to cells
        for a, b in zip(ray[:-1], ray[1:]):
            seg_vec = b - a
            seg_len = np.linalg.norm(seg_vec)
            if seg_len == 0:
                continue
            # sample subdivided points including left endpoint, exclude exact right endpoint
            t = np.linspace(0.0, 1.0, subdivisions, endpoint=False)
            sample_pts = a[None, :] + np.outer(t, seg_vec)  # shape (subdivisions, 3)
            # length contribution per sample
            contrib = seg_len / subdivisions
            # accumulate per cell for this segment
            counts = defaultdict(int)
            for pt in sample_pts:
                idx = _cell_index_from_point(pt, min_coords, intervals, ncx, ncy, ncz)
                if idx is None:
                    # sample outside domain -> ignore or optionally clip
                    continue
                ix, iy, iz = idx
                j = ix + iy * ncx + iz * (ncx * ncy)  # 0-based j
                counts[j] += 1
            # convert counts -> (i,j,val)
            for j, cnt in counts.items():
                row_idx.append(i)
                col_idx.append(j)
                data_vals.append(cnt * contrib)

    # build COO then convert to CSR (this will sum duplicate (i,j) entries automatically)
    if len(data_vals) == 0:
        G = sp.csr_matrix((Nobs, M), dtype=float)
    else:
        G = sp.coo_matrix((data_vals, (row_idx, col_idx)), shape=(Nobs, M)).tocsr()

    meta = {"Nobs": Nobs, "ncx": ncx, "ncy": ncy, "ncz": ncz, "M": M,
            "min_coords": min_coords.tolist(), "intervals": intervals.tolist()}

    return G, meta


def write_G_text(filename, G, one_based=True, float_fmt="{:.6e}"):
    """
    Write sparse G to text format:

    Header1: int number_of_nonzero_entries
    Header2: int N M
    Then rows: i j Gij

    Uses 1-based indexing by default (i,j start at 1). Set one_based=False for 0-based.
    """
    if not sp.isspmatrix_csr(G):
        G = G.tocsr()
    G_coo = G.tocoo()
    nnz = G_coo.nnz
    N, M = G.shape

    offset = 1 if one_based else 0
    with open(filename, "w") as f:
        f.write(f"{nnz}\n")
        f.write(f"{N} {M}\n")
        for r, c, v in zip(G_coo.row, G_coo.col, G_coo.data):
            f.write(f"{r + offset} {c + offset} {float_fmt.format(v)}\n")


def read_G_text(filename, assume_one_based=True):
    """
    Read the text format written by write_G_text. Returns csr_matrix G.
    The reader will attempt to detect 1-based vs 0-based: if the max index equals N or M,
    it will subtract 1 (i.e., interpret as 1-based). If unsure, use assume_one_based flag.
    """
    with open(filename, "r") as f:
        first = f.readline().strip()
        if not first:
            raise ValueError("Empty file")
        nnz = int(first)
        second = f.readline().strip()
        N_str, M_str = second.split()
        N = int(N_str); M = int(M_str)
        rows = []
        cols = []
        vals = []
        for line in f:
            parts = line.strip().split()
            if len(parts) < 3:
                continue
            i = int(parts[0])
            j = int(parts[1])
            v = float(parts[2])
            rows.append(i)
            cols.append(j)
            vals.append(v)

    # detect one-based if requested/detected
    rows = np.array(rows, dtype=int)
    cols = np.array(cols, dtype=int)
    if len(rows) == 0:
        return sp.csr_matrix((N, M), dtype=float)

    # If values appear to be 1-based (max index == N or M) then convert to 0-based
    if assume_one_based:
        rows0 = rows - 1
        cols0 = cols - 1
    else:
        # attempt to auto-detect: if max(rows) == N then probably 1-based
        if rows.max() == N or cols.max() == M:
            rows0 = rows - 1
            cols0 = cols - 1
        else:
            rows0 = rows
            cols0 = cols

    G = sp.coo_matrix((vals, (rows0, cols0)), shape=(N, M)).tocsr()
    return G

# %%
import numpy as np
import matplotlib.pyplot as plt

# try to import gaussian_filter for smoothing; fallback to no smoothing
try:
    from scipy.ndimage import gaussian_filter
    _HAS_GAUSSIAN = True
except Exception:
    _HAS_GAUSSIAN = False

def rays_to_points(rays_saved):
    """
    Given rays_saved list (dicts with key 'ray' each an (N,3) array),
    return an (M,3) array of all points concatenated (x,y,z).
    """
    pts = []
    for rec in rays_saved:
        ray = rec.get("ray")
        if ray is None:
            continue
        ray = np.asarray(ray, dtype=float)
        if ray.size == 0:
            continue
        # ensure shape (N,3)
        if ray.ndim == 1 and ray.size == 3:
            ray = ray.reshape(1,3)
        pts.append(ray)
    if len(pts) == 0:
        return np.empty((0,3))
    return np.vstack(pts)


def compute_density_map(points, x_edges, y_edges, zmin, zmax):
    """
    Compute 2D histogram of points whose z is in [zmin, zmax).
    points: (N,3) array in km: columns x,y,z
    x_edges,y_edges: 1D arrays of bin edges
    returns: density 2D array shape (len(y_edges)-1, len(x_edges)-1)
    """
    if points.size == 0:
        return np.zeros((len(y_edges)-1, len(x_edges)-1), dtype=float)
    sel = (points[:,2] >= zmin) & (points[:,2] < zmax)
    if not np.any(sel):
        return np.zeros((len(y_edges)-1, len(x_edges)-1), dtype=float)
    pts_sel = points[sel]
    H, xedges, yedges = np.histogram2d(pts_sel[:,1], pts_sel[:,0],  # note np.histogram2d uses x=first axis; we use (y,x) so swap
                                       bins=[y_edges, x_edges])
    # H shape: (len(y_edges)-1, len(x_edges)-1)
    return H


def make_depth_slices(zmin, zmax, n_slices=None, slice_thickness=None, overlap=0.0):
    """
    Build list of (z0,z1) pairs covering [zmin,zmax].
    Either n_slices or slice_thickness must be provided.
    overlap: fraction of slice_thickness to overlap (0..<1)
    """
    if n_slices is None and slice_thickness is None:
        raise ValueError("provide n_slices or slice_thickness")
    if n_slices is not None:
        depths = np.linspace(zmin, zmax, n_slices+1)
        slices = [(depths[i], depths[i+1]) for i in range(len(depths)-1)]
    else:
        t = float(slice_thickness)
        if t <= 0:
            raise ValueError("slice_thickness must be > 0")
        step = t * (1.0 - overlap)
        zs = np.arange(zmin, zmax, step)
        slices = [(z, min(z+t, zmax)) for z in zs]
    return slices


def plot_ray_density_slices(p_rays, s_rays,
                            xlim=None, ylim=None, zmin=None, zmax=None,
                            n_slices=6, bins=100, slice_thickness=None, overlap=0.0,
                            smoothing_sigma=1.0, cmap='viridis',
                            station_coords=None, source_coords=None,
                            figsize=(14, 8), vmin_vmax=None):
    """
    Compute and plot ray density slices for P and S rays side-by-side.

    p_rays, s_rays: lists of ray dicts returned by trace_phase_rays
    xlim, ylim: (xmin, xmax), (ymin, ymax) in same units as rays (km). If None, auto from rays.
    zmin, zmax: min and max depth (km) to slice over. If None, auto from rays.
    n_slices: number of depth slices (ignored if slice_thickness provided).
    bins: number of bins in x and y (int) or tuple (nx, ny)
    smoothing_sigma: Gaussian sigma in pixels for smoothing (requires scipy), set 0 for none.
    vmin_vmax: tuple (vmin, vmax) to fix color scale across all panels. If None, computed from P+S data.
    station_coords/source_coords: dict name->(x,y,z) (km); will plot station/source markers on each slice.
    """
    # points arrays
    p_pts = rays_to_points(p_rays)
    s_pts = rays_to_points(s_rays)

    # auto extents
    all_pts = np.vstack([p_pts, s_pts]) if p_pts.size and s_pts.size else (p_pts if p_pts.size else s_pts)
    if all_pts.size == 0:
        raise RuntimeError("No ray points found in either P or S rays.")
    xs = all_pts[:,0]; ys = all_pts[:,1]; zs = all_pts[:,2]
    if xlim is None:
        xmin, xmax = float(xs.min()), float(xs.max())
        padx = 0.02 * (xmax - xmin) if xmax>xmin else 0.1
        xlim = (xmin - padx, xmax + padx)
    if ylim is None:
        ymin, ymax = float(ys.min()), float(ys.max())
        pady = 0.02 * (ymax - ymin) if ymax>ymin else 0.1
        ylim = (ymin - pady, ymax + pady)
    if zmin is None:
        zmin = float(zs.min())
    if zmax is None:
        zmax = float(zs.max())

    # bins
    if isinstance(bins, int):
        nx = bins; ny = bins
    else:
        nx, ny = bins
    x_edges = np.linspace(xlim[0], xlim[1], nx+1)
    y_edges = np.linspace(ylim[0], ylim[1], ny+1)

    # depth slices
    slices = make_depth_slices(zmin, zmax, n_slices=n_slices, slice_thickness=slice_thickness, overlap=overlap)

    # compute maps
    p_maps = []
    s_maps = []
    for (z0,z1) in slices:
        pH = compute_density_map(p_pts, x_edges, y_edges, z0, z1)
        sH = compute_density_map(s_pts, x_edges, y_edges, z0, z1)
        if smoothing_sigma and smoothing_sigma > 0 and _HAS_GAUSSIAN:
            pH = gaussian_filter(pH, sigma=smoothing_sigma)
            sH = gaussian_filter(sH, sigma=smoothing_sigma)
        p_maps.append(pH)
        s_maps.append(sH)

    # color scale
    if vmin_vmax is None:
        global_max = max([m.max() for m in (p_maps + s_maps)]) if (p_maps + s_maps) else 1.0
        vmin, vmax = 0.0, global_max
    else:
        vmin, vmax = vmin_vmax

    # plotting grid: rows = slices, cols = [P, S]
    n = len(slices)
    fig, axes = plt.subplots(nrows=n, ncols=2, figsize=figsize, constrained_layout=True,
                             sharex=True, sharey=True)
    if n == 1:
        axes = axes.reshape(1,2)

    extent = (x_edges[0], x_edges[-1], y_edges[0], y_edges[-1])  # left,right,bottom,top

    for i, (z0,z1) in enumerate(slices):
        # P
        axp = axes[i,0]
        im_p = axp.imshow(np.flipud(p_maps[i]), extent=extent, vmin=vmin, vmax=vmax, aspect='auto', cmap=cmap)
        axp.set_title(f"P density {z0:.2f}–{z1:.2f} km")
        # S
        axs = axes[i,1]
        im_s = axs.imshow(np.flipud(s_maps[i]), extent=extent, vmin=vmin, vmax=vmax, aspect='auto', cmap=cmap)
        axs.set_title(f"S density {z0:.2f}–{z1:.2f} km")

        # overlay station/source markers if provided
        if station_coords:
            sx = [c[0] for c in station_coords.values()]
            sy = [c[1] for c in station_coords.values()]
            axp.scatter(sx, sy, marker='v', s=8, edgecolor='k', linewidth=0.3)
            axs.scatter(sx, sy, marker='v', s=8, edgecolor='k', linewidth=0.3)
        if source_coords:
            sx = [c[0] for c in source_coords.values()]
            sy = [c[1] for c in source_coords.values()]
            axp.scatter(sx, sy, marker='*', s=12, edgecolor='k', linewidth=0.3)
            axs.scatter(sx, sy, marker='*', s=12, edgecolor='k', linewidth=0.3)

        axp.set_xlim(xlim); axp.set_ylim(ylim)
        axs.set_xlim(xlim); axs.set_ylim(ylim)

    # single colorbar on the right
    cbar = fig.colorbar(im_s, ax=axes.ravel().tolist(), fraction=0.015, pad=0.02)
    cbar.set_label("ray hits (counts)")

    plt.suptitle("Ray density slices (columns: P | S)", fontsize=14)
    plt.show()
    return fig, axes

# Convert station/source coords from your loaders to km (they already are in your loaders)
# station_coords: dict name->(x,y,z) in km, source_coords likewise

# quick conversion if your load_station_coords_csv returned meters patched earlier:
# station_coords_km = {k: v/1000.0 for k,v in station_coords.items()}

# Plot 6 slices between min and max depths automatically:
fig, axes = plot_ray_density_slices(p_rays, s_rays,
                                    n_slices=6,
                                    bins=200,
                                    smoothing_sigma=1.0,
                                    station_coords=station_coords,
                                    source_coords=source_coords,
                                    figsize=(12, 14))
