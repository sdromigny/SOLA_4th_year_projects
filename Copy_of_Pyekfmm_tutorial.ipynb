# %% [markdown]
# <a href="https://colab.research.google.com/github/sdromigny/SOLA_4th_year_projects/blob/main/Copy_of_Pyekfmm_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Tutorial to run pyekfmm.
# Try to change the velocity model to a 10x10x10 grid with a first layer at 5.5 km/s and the rest of the layers at 5.76 km/s (keep the source and receiver locations for now as they are)

# %% [markdown]
# #Installing the library
# Please don't hesitate to have a look at the source code: https://github.com/aaspip/pyekfmm

# %%
! pip install pyekfmm
# Out:
# Requirement already satisfied: pyekfmm in /usr/local/lib/python3.12/dist-packages (0.0.8.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pyekfmm) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from pyekfmm) (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from pyekfmm) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyekfmm) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyekfmm) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyekfmm) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyekfmm) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyekfmm) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyekfmm) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyekfmm) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyekfmm) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->pyekfmm) (1.17.0)

# %% [markdown]
# #Importing the libraries

# %%
import pyekfmm as fmm
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #Setting up the grid

# %%
### 3D grid (currently only allow dx=dy=dz)
v1=5.5;
v2=5.76;
#v3=5.76;
nz=300;
nx=500;
ny=500;
dx=0.02;
dz=dx;
dy=dx;
sx=0;
sy=0;
sz=0;

z=np.arange(nz)*dz;
y=np.arange(ny)*dy;
x=np.arange(nx)*dx;

# %% [markdown]
# #Populate the grid with the velocity model values

# %%
## create or load velocity model [z,x,y]
vel3d=v1*np.ones([nz,nx,ny],dtype='float32');
vel3d[3:10, :, :]=v2 #vel3d[100:200, :, :]=v2
#vel3d[200:301, :, :]=v3

## velocity dimension swap [z,x,y] -> [x,y,z]
vxyz=np.swapaxes(np.swapaxes(vel3d,0,1),1,2);
#or
vxyz=np.transpose(vel3d,[1,2,0]);

# %% [markdown]
# #Fast Marching Method calculation: what the traveltimes through the medium will be

# %%
## FMM calculation
t=fmm.eikonal(vxyz.flatten(order='F'),xyz=np.array([sx,sy,sz]),ax=[0,dx,nx],ay=[0,dy,ny],az=[0,dz,nz],order=1);
time=t.reshape(nx,ny,nz,order='F');#first axis (vertical) is x, second is y, third is z
tzxy=np.swapaxes(np.swapaxes(time,1,2),0,1);
#or
tzxy=np.transpose(time,[2,0,1]);

# %% [markdown]
# #Plot the expected traveltimes from FMM and the velocity model

# %%
## plot 3D velocity model
from pyekfmm import plot3d
# plot3d(tzxy,cmap=plt.cm.jet,barlabel='Traveltime (s)',figname='vel3d.png',format='png',dpi=300)
plot3d(tzxy,dz=dz,dx=dx,dy=dy,cmap=plt.cm.jet,barlabel='Traveltime (s)',showf=False,close=False);
plt.gca().set_xlabel("X (km)",fontsize='large', fontweight='normal')
plt.gca().set_ylabel("Y (km)",fontsize='large', fontweight='normal')
plt.gca().set_zlabel("Z (km)",fontsize='large', fontweight='normal')
plt.show()

# plot3d(vel3d,cmap=plt.cm.jet,barlabel='Velocity (km/s)',figname='vel3d.png',format='png',dpi=300)#,figname='time3d.png',format='png',dpi=300)
plot3d(vel3d,x=x,y=y,z=z,cmap=plt.cm.jet,barlabel='Velocity (km/s)',showf=False,close=False);
plt.gca().set_xlabel("X (km)",fontsize='large', fontweight='normal')
plt.gca().set_ylabel("Y (km)",fontsize='large', fontweight='normal')
plt.gca().set_zlabel("Z (km)",fontsize='large', fontweight='normal')
plt.show()

# %% [markdown]
# #How the rays travel through the medium

# %%
# Ray tracing and plotting
from pyekfmm import ray3d
plot3d(tzxy,x=x,y=y,z=z,cmap=plt.cm.jet,barlabel='Traveltime (s)',showf=False,close=False,alpha=0.7);
rz=np.linspace(0,3,4);
rx=0.5*dx/0.01;ry=0.25*dy/0.01;
for z in rz:
	paths=ray3d(time,source=[sx,sy,sz],receiver=[rx,ry,z],trim=0.1,ax=[0,dx,nx],ay=[0,dy,ny],az=[0,dz,nz])
	plt.plot(rx,ry,z,'vb',markersize=10);
	## plot rays
	plt.plot(paths[0,:],paths[1,:],paths[2,:],'g--',markersize=20);

plt.savefig('test_pyekfmm_raytracing3d-0.png',format='png',dpi=300)
# Show Figure
plt.show()
# Out:
# Second break
# Before trim (3, 503)
# After trim (3, 496)
# Second break
# Before trim (3, 510)
# After trim (3, 504)
# Second break
# Before trim (3, 1004)
# After trim (3, 997)
# Second break
# Before trim (3, 1504)
# After trim (3, 1497)
